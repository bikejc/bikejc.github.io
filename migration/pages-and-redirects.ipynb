# %% [markdown]
# # Pages and Redirects: [bikejc.org] / [new.bikejc.org](https://new.bikejc.org)
#
# - Look up [bikejc.org] pages and redirects (from [`pages/` dir][pages] / [`redirects.json`])
# - Check HTTP status codes at [new.bikejc.org] for each page, redirect source, and redirect destination
# - Output results to ["Pages and redirects"] gsheet
#
# [bikejc.org]: https://bikejc.org
# [pages]: https://github.com/bikejc/bikejc.github.io/tree/main/pages
# [`redirects.json`]: https://github.com/bikejc/bikejc.github.io/blob/main/redirects.json
# ["Pages and redirects"]: https://docs.google.com/spreadsheets/d/1dA7hR7kl74Hsvj0mBA9By3T3y3Fkd4jiwjsEWTeWRNw/edit

# %%
from utz import *
from requests import get, head
chdir(dirname(getcwd()))  # move to repo root

# %% [markdown]
# All Git-tracked files:

# %%
git_paths = process.lines('git', 'ls-files')
git_paths = Series(git_paths, name='path')
git_paths
# Out:
# Running: git ls-files
# 0                 .eslintrc.json
# 1      .github/workflows/ghp.yml
# 2                     .gitignore
# 3                CONTRIBUTING.md
# 4                      README.md
#                  ...
# 368      styles/system.theme.css
# 369              styles/user.css
# 370             styles/views.css
# 371                tsconfig.json
# 372           write-redirects.js
# Name: path, Length: 373, dtype: object

# %% [markdown]
# Just the "pages" (`.tsx` files under `pages/`):

# %%
pages = (
    git_paths
    .str.extract(r'pages/(?P<path>[^_].*?)\.tsx').dropna().path
    .str.replace('^index$', '', regex=True)
    .str.replace('/index$', '/', regex=True)
    .sort_values()
)
pages
# Out:
# 38
# 17                                               about/
# 14                                  about/board-members
# 15                                       about/founding
# 16                                        about/history
# 18                         about/non-profit-information
# 23                                            bike-bus/
# 19                                   bike-bus/aqua-line
# 20                                   bike-bus/blue-line
# 21                                   bike-bus/gold-line
# 22                                  bike-bus/green-line
# 25                                         bike-bus/map
# 26                                 bike-bus/orange-line
# 27                                   bike-bus/pink-line
# 28                                 bike-bus/purple-line
# 29                                    bike-bus/red-line
# 30                                 bike-bus/silver-line
# 31                                   bike-bus/teal-line
# 32                                 bike-bus/yellow-line
# 33                                           contact-us
# 37                                              events/
# 35                                   events/bike-jcast/
# 34                    events/bike-jcast/bike-jcast-2017
# 36                                      events/calendar
# 49                                                news/
# 45                                       news/articles/
# 39           news/articles/2016-ward-tour-press-release
# 40    news/articles/bike-jc-awarded-jersey-city-gree...
# 41               news/articles/citi-bike-jc-rebalancing
# 42    news/articles/design-bike-jcs-7th-annual-ward-...
# 43    news/articles/footbridge-liberty-state-park-ar...
# 44    news/articles/grand-street-vision-protected-bi...
# 46    news/articles/installation-jersey-citys-new-bi...
# 47    news/articles/jersey-citys-first-permanent-bik...
# 48      news/articles/job-posting-contract-grant-writer
# 50                                  news/media-coverage
# 55                                            projects/
# 51                                  projects/bike-lanes
# 52                                  projects/bike-racks
# 53                                  projects/bike-share
# 54                                         projects/gsv
# 57                                                  qrs
# 58                                           resources/
# 59                     resources/national-bike-registry
# 60                                 resources/rules-road
# 62                               resources/useful-links
# 65                                             support/
# 63                        support/cool-swag-cool-bikers
# 64                                       support/donate
# 66                                     support/sponsors
# 67                                    support/volunteer
# 68                                             thankyou
# 77                                           ward-tour/
# 71                                      ward-tour/2022/
# 69                                  ward-tour/2022/faqs
# 70                  ward-tour/2022/finish-line-festival
# 72                                 ward-tour/2022/route
# 74                              ward-tour/2022/sponsors
# 75                             ward-tour/2022/volunteer
# 76                                        ward-tour/faq
# Name: path, dtype: object

# %% [markdown]
# Helpers for checking whether a URL:
# - exists (code 200)
# - doesn't exist (code 404)
# - is a redirect (code 301; also returns destination "dst")

# %%
domain = 'bikejc.org'  # current domain
page_prefix = f'https://{domain}/'

def http_head_page(page, domain=None):
    if re.match('^https?://', page):
        url = page
    else:
        if domain is None:
            domain = 'bikejc.org'
        prefix = f'https://{domain}/'
        if page.startswith('/'):
            page = page[1:]
        url = f'{prefix}{page}'
    resp = head(url)
    return resp

def http_head_page_code(page, domain=None):
    resp = http_head_page(page, domain=domain)
    code = resp.status_code
    if code == 301:
        dst = resp.headers['Location']
        if dst.startswith(page_prefix):
            dst = dst[len(page_prefix):]
        else:
            err(f"Unrecognized 301 redirect dst: {dst}")
    else:
        dst = None
    return dict(code=code, dst=dst)

def http_head_page_codes(s, domain=None):
    return sxs(
        s.rename('path'),
        s.apply(http_head_page_code, domain=domain).apply(Series).astype({ 'code': int }),
    )

# %% [markdown]
# ## Check pages' existence at [bikejc.org](https://bikejc.org)
# Some page routes (inferred from repo file paths above) actually redirect to the same path but with a "/" appended:

# %%
# %%time
codes = http_head_page_codes(pages)
codes
# Out:
# CPU times: user 2.96 s, sys: 162 ms, total: 3.12 s
# Wall time: 11.1 s
#                                                  path  code  \
# 38                                                      200
# 17                                             about/   200
# 14                                about/board-members   301
# 15                                     about/founding   301
# 16                                      about/history   301
# 18                       about/non-profit-information   301
# 23                                          bike-bus/   200
# 19                                 bike-bus/aqua-line   301
# 20                                 bike-bus/blue-line   301
# 21                                 bike-bus/gold-line   301
# 22                                bike-bus/green-line   301
# 25                                       bike-bus/map   301
# 26                               bike-bus/orange-line   301
# 27                                 bike-bus/pink-line   301
# 28                               bike-bus/purple-line   301
# 29                                  bike-bus/red-line   301
# 30                               bike-bus/silver-line   301
# 31                                 bike-bus/teal-line   301
# 32                               bike-bus/yellow-line   301
# 33                                         contact-us   301
# 37                                            events/   200
# 35                                 events/bike-jcast/   200
# 34                  events/bike-jcast/bike-jcast-2017   301
# 36                                    events/calendar   301
# 49                                              news/   200
# 45                                     news/articles/   200
# 39         news/articles/2016-ward-tour-press-release   301
# 40  news/articles/bike-jc-awarded-jersey-city-gree...   301
# 41             news/articles/citi-bike-jc-rebalancing   301
# 42  news/articles/design-bike-jcs-7th-annual-ward-...   301
# 43  news/articles/footbridge-liberty-state-park-ar...   301
# 44  news/articles/grand-street-vision-protected-bi...   301
# 46  news/articles/installation-jersey-citys-new-bi...   301
# 47  news/articles/jersey-citys-first-permanent-bik...   301
# 48    news/articles/job-posting-contract-grant-writer   301
# 50                                news/media-coverage   301
# 55                                          projects/   200
# 51                                projects/bike-lanes   301
# 52                                projects/bike-racks   301
# 53                                projects/bike-share   301
# 54                                       projects/gsv   301
# 57                                                qrs   301
# 58                                         resources/   200
# 59                   resources/national-bike-registry   301
# 60                               resources/rules-road   301
# 62                             resources/useful-links   301
# 65                                           support/   200
# 63                      support/cool-swag-cool-bikers   301
# 64                                     support/donate   301
# 66                                   support/sponsors   301
# 67                                  support/volunteer   301
# 68                                           thankyou   301
# 77                                         ward-tour/   200
# 71                                    ward-tour/2022/   200
# 69                                ward-tour/2022/faqs   301
# 70                ward-tour/2022/finish-line-festival   301
# 72                               ward-tour/2022/route   301
# 74                            ward-tour/2022/sponsors   301
# 75                           ward-tour/2022/volunteer   301
# 76                                      ward-tour/faq   301
#
#                                                   dst
# 38                                                NaN
# 17                                                NaN
# 14                               about/board-members/
# 15                                    about/founding/
# 16                                     about/history/
# 18                      about/non-profit-information/
# 23                                                NaN
# 19                                bike-bus/aqua-line/
# 20                                bike-bus/blue-line/
# 21                                bike-bus/gold-line/
# 22                               bike-bus/green-line/
# 25                                      bike-bus/map/
# 26                              bike-bus/orange-line/
# 27                                bike-bus/pink-line/
# 28                              bike-bus/purple-line/
# 29                                 bike-bus/red-line/
# 30                              bike-bus/silver-line/
# 31                                bike-bus/teal-line/
# 32                              bike-bus/yellow-line/
# 33                                        contact-us/
# 37                                                NaN
# 35                                                NaN
# 34                 events/bike-jcast/bike-jcast-2017/
# 36                                   events/calendar/
# 49                                                NaN
# 45                                                NaN
# 39        news/articles/2016-ward-tour-press-release/
# 40  news/articles/bike-jc-awarded-jersey-city-gree...
# 41            news/articles/citi-bike-jc-rebalancing/
# 42  news/articles/design-bike-jcs-7th-annual-ward-...
# 43  news/articles/footbridge-liberty-state-park-ar...
# 44  news/articles/grand-street-vision-protected-bi...
# 46  news/articles/installation-jersey-citys-new-bi...
# 47  news/articles/jersey-citys-first-permanent-bik...
# 48   news/articles/job-posting-contract-grant-writer/
# 50                               news/media-coverage/
# 55                                                NaN
# 51                               projects/bike-lanes/
# 52                               projects/bike-racks/
# 53                               projects/bike-share/
# 54                                      projects/gsv/
# 57                                               qrs/
# 58                                                NaN
# 59                  resources/national-bike-registry/
# 60                              resources/rules-road/
# 62                            resources/useful-links/
# 65                                                NaN
# 63                     support/cool-swag-cool-bikers/
# 64                                    support/donate/
# 66                                  support/sponsors/
# 67                                 support/volunteer/
# 68                                          thankyou/
# 77                                                NaN
# 71                                                NaN
# 69                               ward-tour/2022/faqs/
# 70               ward-tour/2022/finish-line-festival/
# 72                              ward-tour/2022/route/
# 74                           ward-tour/2022/sponsors/
# 75                          ward-tour/2022/volunteer/
# 76                                     ward-tour/faq/

# %% [markdown]
# Separate 200's from 301's:

# %%
is_200 = codes.dst.isna()
redirects = codes[~is_200]
oks = codes[is_200]
redirects
# Out:
#                                                  path  code  \
# 14                                about/board-members   301
# 15                                     about/founding   301
# 16                                      about/history   301
# 18                       about/non-profit-information   301
# 19                                 bike-bus/aqua-line   301
# 20                                 bike-bus/blue-line   301
# 21                                 bike-bus/gold-line   301
# 22                                bike-bus/green-line   301
# 25                                       bike-bus/map   301
# 26                               bike-bus/orange-line   301
# 27                                 bike-bus/pink-line   301
# 28                               bike-bus/purple-line   301
# 29                                  bike-bus/red-line   301
# 30                               bike-bus/silver-line   301
# 31                                 bike-bus/teal-line   301
# 32                               bike-bus/yellow-line   301
# 33                                         contact-us   301
# 34                  events/bike-jcast/bike-jcast-2017   301
# 36                                    events/calendar   301
# 39         news/articles/2016-ward-tour-press-release   301
# 40  news/articles/bike-jc-awarded-jersey-city-gree...   301
# 41             news/articles/citi-bike-jc-rebalancing   301
# 42  news/articles/design-bike-jcs-7th-annual-ward-...   301
# 43  news/articles/footbridge-liberty-state-park-ar...   301
# 44  news/articles/grand-street-vision-protected-bi...   301
# 46  news/articles/installation-jersey-citys-new-bi...   301
# 47  news/articles/jersey-citys-first-permanent-bik...   301
# 48    news/articles/job-posting-contract-grant-writer   301
# 50                                news/media-coverage   301
# 51                                projects/bike-lanes   301
# 52                                projects/bike-racks   301
# 53                                projects/bike-share   301
# 54                                       projects/gsv   301
# 57                                                qrs   301
# 59                   resources/national-bike-registry   301
# 60                               resources/rules-road   301
# 62                             resources/useful-links   301
# 63                      support/cool-swag-cool-bikers   301
# 64                                     support/donate   301
# 66                                   support/sponsors   301
# 67                                  support/volunteer   301
# 68                                           thankyou   301
# 69                                ward-tour/2022/faqs   301
# 70                ward-tour/2022/finish-line-festival   301
# 72                               ward-tour/2022/route   301
# 74                            ward-tour/2022/sponsors   301
# 75                           ward-tour/2022/volunteer   301
# 76                                      ward-tour/faq   301
#
#                                                   dst
# 14                               about/board-members/
# 15                                    about/founding/
# 16                                     about/history/
# 18                      about/non-profit-information/
# 19                                bike-bus/aqua-line/
# 20                                bike-bus/blue-line/
# 21                                bike-bus/gold-line/
# 22                               bike-bus/green-line/
# 25                                      bike-bus/map/
# 26                              bike-bus/orange-line/
# 27                                bike-bus/pink-line/
# 28                              bike-bus/purple-line/
# 29                                 bike-bus/red-line/
# 30                              bike-bus/silver-line/
# 31                                bike-bus/teal-line/
# 32                              bike-bus/yellow-line/
# 33                                        contact-us/
# 34                 events/bike-jcast/bike-jcast-2017/
# 36                                   events/calendar/
# 39        news/articles/2016-ward-tour-press-release/
# 40  news/articles/bike-jc-awarded-jersey-city-gree...
# 41            news/articles/citi-bike-jc-rebalancing/
# 42  news/articles/design-bike-jcs-7th-annual-ward-...
# 43  news/articles/footbridge-liberty-state-park-ar...
# 44  news/articles/grand-street-vision-protected-bi...
# 46  news/articles/installation-jersey-citys-new-bi...
# 47  news/articles/jersey-citys-first-permanent-bik...
# 48   news/articles/job-posting-contract-grant-writer/
# 50                               news/media-coverage/
# 51                               projects/bike-lanes/
# 52                               projects/bike-racks/
# 53                               projects/bike-share/
# 54                                      projects/gsv/
# 57                                               qrs/
# 59                  resources/national-bike-registry/
# 60                              resources/rules-road/
# 62                            resources/useful-links/
# 63                     support/cool-swag-cool-bikers/
# 64                                    support/donate/
# 66                                  support/sponsors/
# 67                                 support/volunteer/
# 68                                          thankyou/
# 69                               ward-tour/2022/faqs/
# 70               ward-tour/2022/finish-line-festival/
# 72                              ward-tour/2022/route/
# 74                           ward-tour/2022/sponsors/
# 75                          ward-tour/2022/volunteer/
# 76                                     ward-tour/faq/

# %% [markdown]
# Verify that the redirected pages all resolve:

# %%
# %%time
codes2 = http_head_page_codes(redirects.dst)
assert codes2.dst.isna().all()
codes2
# Out:
# CPU times: user 1.72 s, sys: 135 ms, total: 1.85 s
# Wall time: 8.43 s
#                                                  path  code  dst
# 14                               about/board-members/   200  NaN
# 15                                    about/founding/   200  NaN
# 16                                     about/history/   200  NaN
# 18                      about/non-profit-information/   200  NaN
# 19                                bike-bus/aqua-line/   200  NaN
# 20                                bike-bus/blue-line/   200  NaN
# 21                                bike-bus/gold-line/   200  NaN
# 22                               bike-bus/green-line/   200  NaN
# 25                                      bike-bus/map/   200  NaN
# 26                              bike-bus/orange-line/   200  NaN
# 27                                bike-bus/pink-line/   200  NaN
# 28                              bike-bus/purple-line/   200  NaN
# 29                                 bike-bus/red-line/   200  NaN
# 30                              bike-bus/silver-line/   200  NaN
# 31                                bike-bus/teal-line/   200  NaN
# 32                              bike-bus/yellow-line/   200  NaN
# 33                                        contact-us/   200  NaN
# 34                 events/bike-jcast/bike-jcast-2017/   200  NaN
# 36                                   events/calendar/   200  NaN
# 39        news/articles/2016-ward-tour-press-release/   200  NaN
# 40  news/articles/bike-jc-awarded-jersey-city-gree...   200  NaN
# 41            news/articles/citi-bike-jc-rebalancing/   200  NaN
# 42  news/articles/design-bike-jcs-7th-annual-ward-...   200  NaN
# 43  news/articles/footbridge-liberty-state-park-ar...   200  NaN
# 44  news/articles/grand-street-vision-protected-bi...   200  NaN
# 46  news/articles/installation-jersey-citys-new-bi...   200  NaN
# 47  news/articles/jersey-citys-first-permanent-bik...   200  NaN
# 48   news/articles/job-posting-contract-grant-writer/   200  NaN
# 50                               news/media-coverage/   200  NaN
# 51                               projects/bike-lanes/   200  NaN
# 52                               projects/bike-racks/   200  NaN
# 53                               projects/bike-share/   200  NaN
# 54                                      projects/gsv/   200  NaN
# 57                                               qrs/   200  NaN
# 59                  resources/national-bike-registry/   200  NaN
# 60                              resources/rules-road/   200  NaN
# 62                            resources/useful-links/   200  NaN
# 63                     support/cool-swag-cool-bikers/   200  NaN
# 64                                    support/donate/   200  NaN
# 66                                  support/sponsors/   200  NaN
# 67                                 support/volunteer/   200  NaN
# 68                                          thankyou/   200  NaN
# 69                               ward-tour/2022/faqs/   200  NaN
# 70               ward-tour/2022/finish-line-festival/   200  NaN
# 72                              ward-tour/2022/route/   200  NaN
# 74                           ward-tour/2022/sponsors/   200  NaN
# 75                          ward-tour/2022/volunteer/   200  NaN
# 76                                     ward-tour/faq/   200  NaN

# %% [markdown]
# These page paths resolved without redirecting (`/index.tsx` files)

# %%
oks
# Out:
#                   path  code  dst
# 38                       200  NaN
# 17              about/   200  NaN
# 23           bike-bus/   200  NaN
# 37             events/   200  NaN
# 35  events/bike-jcast/   200  NaN
# 49               news/   200  NaN
# 45      news/articles/   200  NaN
# 55           projects/   200  NaN
# 58          resources/   200  NaN
# 65            support/   200  NaN
# 77          ward-tour/   200  NaN
# 71     ward-tour/2022/   200  NaN

# %% [markdown]
# ## Connect to ["Pages and redirects" gsheet](https://docs.google.com/spreadsheets/d/1dA7hR7kl74Hsvj0mBA9By3T3y3Fkd4jiwjsEWTeWRNw/edit)

# %%
from gspread_pandas import Spread, Client

# %%
spread = Spread('Pages and redirects')

# %% [markdown]
# ## Pages (old and new site)

# %% [markdown]
# Staging domain for new/demo site: [new.bikejc.org](https://new.bikejc.org)

# %%
new_domain = 'new.bikejc.org'
new_page_prefix = f'https://{new_domain}/'

# %% [markdown]
# Combine pages that resolved immediately + those that redirected to a trailing-slash version:

# %%
paths = concat([ oks, codes2 ]).path.sort_values()
paths = (
    sxs(
        paths,
        (
            paths
            .apply(lambda path: f'{page_prefix}{path}')
            .rename('url')
        ),
        (
            paths
            .apply(lambda path: f'{new_page_prefix}{path}')
            .rename('new_url')
        ),
    )
    .reset_index(drop=True)
)
paths
# Out:
#                                                  path  \
# 0
# 1                                              about/
# 2                                about/board-members/
# 3                                     about/founding/
# 4                                      about/history/
# 5                       about/non-profit-information/
# 6                                           bike-bus/
# 7                                 bike-bus/aqua-line/
# 8                                 bike-bus/blue-line/
# 9                                 bike-bus/gold-line/
# 10                               bike-bus/green-line/
# 11                                      bike-bus/map/
# 12                              bike-bus/orange-line/
# 13                                bike-bus/pink-line/
# 14                              bike-bus/purple-line/
# 15                                 bike-bus/red-line/
# 16                              bike-bus/silver-line/
# 17                                bike-bus/teal-line/
# 18                              bike-bus/yellow-line/
# 19                                        contact-us/
# 20                                            events/
# 21                                 events/bike-jcast/
# 22                 events/bike-jcast/bike-jcast-2017/
# 23                                   events/calendar/
# 24                                              news/
# 25                                     news/articles/
# 26        news/articles/2016-ward-tour-press-release/
# 27  news/articles/bike-jc-awarded-jersey-city-gree...
# 28            news/articles/citi-bike-jc-rebalancing/
# 29  news/articles/design-bike-jcs-7th-annual-ward-...
# 30  news/articles/footbridge-liberty-state-park-ar...
# 31  news/articles/grand-street-vision-protected-bi...
# 32  news/articles/installation-jersey-citys-new-bi...
# 33  news/articles/jersey-citys-first-permanent-bik...
# 34   news/articles/job-posting-contract-grant-writer/
# 35                               news/media-coverage/
# 36                                          projects/
# 37                               projects/bike-lanes/
# 38                               projects/bike-racks/
# 39                               projects/bike-share/
# 40                                      projects/gsv/
# 41                                               qrs/
# 42                                         resources/
# 43                  resources/national-bike-registry/
# 44                              resources/rules-road/
# 45                            resources/useful-links/
# 46                                           support/
# 47                     support/cool-swag-cool-bikers/
# 48                                    support/donate/
# 49                                  support/sponsors/
# 50                                 support/volunteer/
# 51                                          thankyou/
# 52                                         ward-tour/
# 53                                    ward-tour/2022/
# 54                               ward-tour/2022/faqs/
# 55               ward-tour/2022/finish-line-festival/
# 56                              ward-tour/2022/route/
# 57                           ward-tour/2022/sponsors/
# 58                          ward-tour/2022/volunteer/
# 59                                     ward-tour/faq/
#
#                                                   url  \
# 0                                 https://bikejc.org/
# 1                           https://bikejc.org/about/
# 2             https://bikejc.org/about/board-members/
# 3                  https://bikejc.org/about/founding/
# 4                   https://bikejc.org/about/history/
# 5    https://bikejc.org/about/non-profit-information/
# 6                        https://bikejc.org/bike-bus/
# 7              https://bikejc.org/bike-bus/aqua-line/
# 8              https://bikejc.org/bike-bus/blue-line/
# 9              https://bikejc.org/bike-bus/gold-line/
# 10            https://bikejc.org/bike-bus/green-line/
# 11                   https://bikejc.org/bike-bus/map/
# 12           https://bikejc.org/bike-bus/orange-line/
# 13             https://bikejc.org/bike-bus/pink-line/
# 14           https://bikejc.org/bike-bus/purple-line/
# 15              https://bikejc.org/bike-bus/red-line/
# 16           https://bikejc.org/bike-bus/silver-line/
# 17             https://bikejc.org/bike-bus/teal-line/
# 18           https://bikejc.org/bike-bus/yellow-line/
# 19                     https://bikejc.org/contact-us/
# 20                         https://bikejc.org/events/
# 21              https://bikejc.org/events/bike-jcast/
# 22  https://bikejc.org/events/bike-jcast/bike-jcas...
# 23                https://bikejc.org/events/calendar/
# 24                           https://bikejc.org/news/
# 25                  https://bikejc.org/news/articles/
# 26  https://bikejc.org/news/articles/2016-ward-tou...
# 27  https://bikejc.org/news/articles/bike-jc-award...
# 28  https://bikejc.org/news/articles/citi-bike-jc-...
# 29  https://bikejc.org/news/articles/design-bike-j...
# 30  https://bikejc.org/news/articles/footbridge-li...
# 31  https://bikejc.org/news/articles/grand-street-...
# 32  https://bikejc.org/news/articles/installation-...
# 33  https://bikejc.org/news/articles/jersey-citys-...
# 34  https://bikejc.org/news/articles/job-posting-c...
# 35            https://bikejc.org/news/media-coverage/
# 36                       https://bikejc.org/projects/
# 37            https://bikejc.org/projects/bike-lanes/
# 38            https://bikejc.org/projects/bike-racks/
# 39            https://bikejc.org/projects/bike-share/
# 40                   https://bikejc.org/projects/gsv/
# 41                            https://bikejc.org/qrs/
# 42                      https://bikejc.org/resources/
# 43  https://bikejc.org/resources/national-bike-reg...
# 44           https://bikejc.org/resources/rules-road/
# 45         https://bikejc.org/resources/useful-links/
# 46                        https://bikejc.org/support/
# 47  https://bikejc.org/support/cool-swag-cool-bikers/
# 48                 https://bikejc.org/support/donate/
# 49               https://bikejc.org/support/sponsors/
# 50              https://bikejc.org/support/volunteer/
# 51                       https://bikejc.org/thankyou/
# 52                      https://bikejc.org/ward-tour/
# 53                 https://bikejc.org/ward-tour/2022/
# 54            https://bikejc.org/ward-tour/2022/faqs/
# 55  https://bikejc.org/ward-tour/2022/finish-line-...
# 56           https://bikejc.org/ward-tour/2022/route/
# 57        https://bikejc.org/ward-tour/2022/sponsors/
# 58       https://bikejc.org/ward-tour/2022/volunteer/
# 59                  https://bikejc.org/ward-tour/faq/
#
#                                               new_url
# 0                             https://new.bikejc.org/
# 1                       https://new.bikejc.org/about/
# 2         https://new.bikejc.org/about/board-members/
# 3              https://new.bikejc.org/about/founding/
# 4               https://new.bikejc.org/about/history/
# 5   https://new.bikejc.org/about/non-profit-inform...
# 6                    https://new.bikejc.org/bike-bus/
# 7          https://new.bikejc.org/bike-bus/aqua-line/
# 8          https://new.bikejc.org/bike-bus/blue-line/
# 9          https://new.bikejc.org/bike-bus/gold-line/
# 10        https://new.bikejc.org/bike-bus/green-line/
# 11               https://new.bikejc.org/bike-bus/map/
# 12       https://new.bikejc.org/bike-bus/orange-line/
# 13         https://new.bikejc.org/bike-bus/pink-line/
# 14       https://new.bikejc.org/bike-bus/purple-line/
# 15          https://new.bikejc.org/bike-bus/red-line/
# 16       https://new.bikejc.org/bike-bus/silver-line/
# 17         https://new.bikejc.org/bike-bus/teal-line/
# 18       https://new.bikejc.org/bike-bus/yellow-line/
# 19                 https://new.bikejc.org/contact-us/
# 20                     https://new.bikejc.org/events/
# 21          https://new.bikejc.org/events/bike-jcast/
# 22  https://new.bikejc.org/events/bike-jcast/bike-...
# 23            https://new.bikejc.org/events/calendar/
# 24                       https://new.bikejc.org/news/
# 25              https://new.bikejc.org/news/articles/
# 26  https://new.bikejc.org/news/articles/2016-ward...
# 27  https://new.bikejc.org/news/articles/bike-jc-a...
# 28  https://new.bikejc.org/news/articles/citi-bike...
# 29  https://new.bikejc.org/news/articles/design-bi...
# 30  https://new.bikejc.org/news/articles/footbridg...
# 31  https://new.bikejc.org/news/articles/grand-str...
# 32  https://new.bikejc.org/news/articles/installat...
# 33  https://new.bikejc.org/news/articles/jersey-ci...
# 34  https://new.bikejc.org/news/articles/job-posti...
# 35        https://new.bikejc.org/news/media-coverage/
# 36                   https://new.bikejc.org/projects/
# 37        https://new.bikejc.org/projects/bike-lanes/
# 38        https://new.bikejc.org/projects/bike-racks/
# 39        https://new.bikejc.org/projects/bike-share/
# 40               https://new.bikejc.org/projects/gsv/
# 41                        https://new.bikejc.org/qrs/
# 42                  https://new.bikejc.org/resources/
# 43  https://new.bikejc.org/resources/national-bike...
# 44       https://new.bikejc.org/resources/rules-road/
# 45     https://new.bikejc.org/resources/useful-links/
# 46                    https://new.bikejc.org/support/
# 47  https://new.bikejc.org/support/cool-swag-cool-...
# 48             https://new.bikejc.org/support/donate/
# 49           https://new.bikejc.org/support/sponsors/
# 50          https://new.bikejc.org/support/volunteer/
# 51                   https://new.bikejc.org/thankyou/
# 52                  https://new.bikejc.org/ward-tour/
# 53             https://new.bikejc.org/ward-tour/2022/
# 54        https://new.bikejc.org/ward-tour/2022/faqs/
# 55  https://new.bikejc.org/ward-tour/2022/finish-l...
# 56       https://new.bikejc.org/ward-tour/2022/route/
# 57    https://new.bikejc.org/ward-tour/2022/sponsors/
# 58   https://new.bikejc.org/ward-tour/2022/volunteer/
# 59              https://new.bikejc.org/ward-tour/faq/

# %% [markdown]
# ### Check pages' existence at [new.bikejc.org](https://new.bikejc.org)

# %%
new_pages = http_head_page_codes(paths.new_url)
new_pages
# Out:
#                                                  path  code  dst
# 0                             https://new.bikejc.org/   200  NaN
# 1                       https://new.bikejc.org/about/   200  NaN
# 2         https://new.bikejc.org/about/board-members/   200  NaN
# 3              https://new.bikejc.org/about/founding/   200  NaN
# 4               https://new.bikejc.org/about/history/   200  NaN
# 5   https://new.bikejc.org/about/non-profit-inform...   200  NaN
# 6                    https://new.bikejc.org/bike-bus/   200  NaN
# 7          https://new.bikejc.org/bike-bus/aqua-line/   200  NaN
# 8          https://new.bikejc.org/bike-bus/blue-line/   200  NaN
# 9          https://new.bikejc.org/bike-bus/gold-line/   200  NaN
# 10        https://new.bikejc.org/bike-bus/green-line/   200  NaN
# 11               https://new.bikejc.org/bike-bus/map/   200  NaN
# 12       https://new.bikejc.org/bike-bus/orange-line/   200  NaN
# 13         https://new.bikejc.org/bike-bus/pink-line/   200  NaN
# 14       https://new.bikejc.org/bike-bus/purple-line/   200  NaN
# 15          https://new.bikejc.org/bike-bus/red-line/   200  NaN
# 16       https://new.bikejc.org/bike-bus/silver-line/   200  NaN
# 17         https://new.bikejc.org/bike-bus/teal-line/   200  NaN
# 18       https://new.bikejc.org/bike-bus/yellow-line/   200  NaN
# 19                 https://new.bikejc.org/contact-us/   404  NaN
# 20                     https://new.bikejc.org/events/   200  NaN
# 21          https://new.bikejc.org/events/bike-jcast/   200  NaN
# 22  https://new.bikejc.org/events/bike-jcast/bike-...   200  NaN
# 23            https://new.bikejc.org/events/calendar/   200  NaN
# 24                       https://new.bikejc.org/news/   404  NaN
# 25              https://new.bikejc.org/news/articles/   404  NaN
# 26  https://new.bikejc.org/news/articles/2016-ward...   404  NaN
# 27  https://new.bikejc.org/news/articles/bike-jc-a...   404  NaN
# 28  https://new.bikejc.org/news/articles/citi-bike...   404  NaN
# 29  https://new.bikejc.org/news/articles/design-bi...   404  NaN
# 30  https://new.bikejc.org/news/articles/footbridg...   404  NaN
# 31  https://new.bikejc.org/news/articles/grand-str...   404  NaN
# 32  https://new.bikejc.org/news/articles/installat...   404  NaN
# 33  https://new.bikejc.org/news/articles/jersey-ci...   404  NaN
# 34  https://new.bikejc.org/news/articles/job-posti...   404  NaN
# 35        https://new.bikejc.org/news/media-coverage/   404  NaN
# 36                   https://new.bikejc.org/projects/   404  NaN
# 37        https://new.bikejc.org/projects/bike-lanes/   404  NaN
# 38        https://new.bikejc.org/projects/bike-racks/   404  NaN
# 39        https://new.bikejc.org/projects/bike-share/   404  NaN
# 40               https://new.bikejc.org/projects/gsv/   404  NaN
# 41                        https://new.bikejc.org/qrs/   404  NaN
# 42                  https://new.bikejc.org/resources/   404  NaN
# 43  https://new.bikejc.org/resources/national-bike...   404  NaN
# 44       https://new.bikejc.org/resources/rules-road/   404  NaN
# 45     https://new.bikejc.org/resources/useful-links/   404  NaN
# 46                    https://new.bikejc.org/support/   404  NaN
# 47  https://new.bikejc.org/support/cool-swag-cool-...   404  NaN
# 48             https://new.bikejc.org/support/donate/   404  NaN
# 49           https://new.bikejc.org/support/sponsors/   404  NaN
# 50          https://new.bikejc.org/support/volunteer/   404  NaN
# 51                   https://new.bikejc.org/thankyou/   404  NaN
# 52                  https://new.bikejc.org/ward-tour/   200  NaN
# 53             https://new.bikejc.org/ward-tour/2022/   200  NaN
# 54        https://new.bikejc.org/ward-tour/2022/faqs/   200  NaN
# 55  https://new.bikejc.org/ward-tour/2022/finish-l...   200  NaN
# 56       https://new.bikejc.org/ward-tour/2022/route/   200  NaN
# 57    https://new.bikejc.org/ward-tour/2022/sponsors/   200  NaN
# 58   https://new.bikejc.org/ward-tour/2022/volunteer/   200  NaN
# 59              https://new.bikejc.org/ward-tour/faq/   200  NaN

# %%
new_codes = new_pages.code.rename('new_url_code')
pages = sxs(paths, new_codes)
pages
# Out:
#                                                  path  \
# 0
# 1                                              about/
# 2                                about/board-members/
# 3                                     about/founding/
# 4                                      about/history/
# 5                       about/non-profit-information/
# 6                                           bike-bus/
# 7                                 bike-bus/aqua-line/
# 8                                 bike-bus/blue-line/
# 9                                 bike-bus/gold-line/
# 10                               bike-bus/green-line/
# 11                                      bike-bus/map/
# 12                              bike-bus/orange-line/
# 13                                bike-bus/pink-line/
# 14                              bike-bus/purple-line/
# 15                                 bike-bus/red-line/
# 16                              bike-bus/silver-line/
# 17                                bike-bus/teal-line/
# 18                              bike-bus/yellow-line/
# 19                                        contact-us/
# 20                                            events/
# 21                                 events/bike-jcast/
# 22                 events/bike-jcast/bike-jcast-2017/
# 23                                   events/calendar/
# 24                                              news/
# 25                                     news/articles/
# 26        news/articles/2016-ward-tour-press-release/
# 27  news/articles/bike-jc-awarded-jersey-city-gree...
# 28            news/articles/citi-bike-jc-rebalancing/
# 29  news/articles/design-bike-jcs-7th-annual-ward-...
# 30  news/articles/footbridge-liberty-state-park-ar...
# 31  news/articles/grand-street-vision-protected-bi...
# 32  news/articles/installation-jersey-citys-new-bi...
# 33  news/articles/jersey-citys-first-permanent-bik...
# 34   news/articles/job-posting-contract-grant-writer/
# 35                               news/media-coverage/
# 36                                          projects/
# 37                               projects/bike-lanes/
# 38                               projects/bike-racks/
# 39                               projects/bike-share/
# 40                                      projects/gsv/
# 41                                               qrs/
# 42                                         resources/
# 43                  resources/national-bike-registry/
# 44                              resources/rules-road/
# 45                            resources/useful-links/
# 46                                           support/
# 47                     support/cool-swag-cool-bikers/
# 48                                    support/donate/
# 49                                  support/sponsors/
# 50                                 support/volunteer/
# 51                                          thankyou/
# 52                                         ward-tour/
# 53                                    ward-tour/2022/
# 54                               ward-tour/2022/faqs/
# 55               ward-tour/2022/finish-line-festival/
# 56                              ward-tour/2022/route/
# 57                           ward-tour/2022/sponsors/
# 58                          ward-tour/2022/volunteer/
# 59                                     ward-tour/faq/
#
#                                                   url  \
# 0                                 https://bikejc.org/
# 1                           https://bikejc.org/about/
# 2             https://bikejc.org/about/board-members/
# 3                  https://bikejc.org/about/founding/
# 4                   https://bikejc.org/about/history/
# 5    https://bikejc.org/about/non-profit-information/
# 6                        https://bikejc.org/bike-bus/
# 7              https://bikejc.org/bike-bus/aqua-line/
# 8              https://bikejc.org/bike-bus/blue-line/
# 9              https://bikejc.org/bike-bus/gold-line/
# 10            https://bikejc.org/bike-bus/green-line/
# 11                   https://bikejc.org/bike-bus/map/
# 12           https://bikejc.org/bike-bus/orange-line/
# 13             https://bikejc.org/bike-bus/pink-line/
# 14           https://bikejc.org/bike-bus/purple-line/
# 15              https://bikejc.org/bike-bus/red-line/
# 16           https://bikejc.org/bike-bus/silver-line/
# 17             https://bikejc.org/bike-bus/teal-line/
# 18           https://bikejc.org/bike-bus/yellow-line/
# 19                     https://bikejc.org/contact-us/
# 20                         https://bikejc.org/events/
# 21              https://bikejc.org/events/bike-jcast/
# 22  https://bikejc.org/events/bike-jcast/bike-jcas...
# 23                https://bikejc.org/events/calendar/
# 24                           https://bikejc.org/news/
# 25                  https://bikejc.org/news/articles/
# 26  https://bikejc.org/news/articles/2016-ward-tou...
# 27  https://bikejc.org/news/articles/bike-jc-award...
# 28  https://bikejc.org/news/articles/citi-bike-jc-...
# 29  https://bikejc.org/news/articles/design-bike-j...
# 30  https://bikejc.org/news/articles/footbridge-li...
# 31  https://bikejc.org/news/articles/grand-street-...
# 32  https://bikejc.org/news/articles/installation-...
# 33  https://bikejc.org/news/articles/jersey-citys-...
# 34  https://bikejc.org/news/articles/job-posting-c...
# 35            https://bikejc.org/news/media-coverage/
# 36                       https://bikejc.org/projects/
# 37            https://bikejc.org/projects/bike-lanes/
# 38            https://bikejc.org/projects/bike-racks/
# 39            https://bikejc.org/projects/bike-share/
# 40                   https://bikejc.org/projects/gsv/
# 41                            https://bikejc.org/qrs/
# 42                      https://bikejc.org/resources/
# 43  https://bikejc.org/resources/national-bike-reg...
# 44           https://bikejc.org/resources/rules-road/
# 45         https://bikejc.org/resources/useful-links/
# 46                        https://bikejc.org/support/
# 47  https://bikejc.org/support/cool-swag-cool-bikers/
# 48                 https://bikejc.org/support/donate/
# 49               https://bikejc.org/support/sponsors/
# 50              https://bikejc.org/support/volunteer/
# 51                       https://bikejc.org/thankyou/
# 52                      https://bikejc.org/ward-tour/
# 53                 https://bikejc.org/ward-tour/2022/
# 54            https://bikejc.org/ward-tour/2022/faqs/
# 55  https://bikejc.org/ward-tour/2022/finish-line-...
# 56           https://bikejc.org/ward-tour/2022/route/
# 57        https://bikejc.org/ward-tour/2022/sponsors/
# 58       https://bikejc.org/ward-tour/2022/volunteer/
# 59                  https://bikejc.org/ward-tour/faq/
#
#                                               new_url  new_url_code
# 0                             https://new.bikejc.org/           200
# 1                       https://new.bikejc.org/about/           200
# 2         https://new.bikejc.org/about/board-members/           200
# 3              https://new.bikejc.org/about/founding/           200
# 4               https://new.bikejc.org/about/history/           200
# 5   https://new.bikejc.org/about/non-profit-inform...           200
# 6                    https://new.bikejc.org/bike-bus/           200
# 7          https://new.bikejc.org/bike-bus/aqua-line/           200
# 8          https://new.bikejc.org/bike-bus/blue-line/           200
# 9          https://new.bikejc.org/bike-bus/gold-line/           200
# 10        https://new.bikejc.org/bike-bus/green-line/           200
# 11               https://new.bikejc.org/bike-bus/map/           200
# 12       https://new.bikejc.org/bike-bus/orange-line/           200
# 13         https://new.bikejc.org/bike-bus/pink-line/           200
# 14       https://new.bikejc.org/bike-bus/purple-line/           200
# 15          https://new.bikejc.org/bike-bus/red-line/           200
# 16       https://new.bikejc.org/bike-bus/silver-line/           200
# 17         https://new.bikejc.org/bike-bus/teal-line/           200
# 18       https://new.bikejc.org/bike-bus/yellow-line/           200
# 19                 https://new.bikejc.org/contact-us/           404
# 20                     https://new.bikejc.org/events/           200
# 21          https://new.bikejc.org/events/bike-jcast/           200
# 22  https://new.bikejc.org/events/bike-jcast/bike-...           200
# 23            https://new.bikejc.org/events/calendar/           200
# 24                       https://new.bikejc.org/news/           404
# 25              https://new.bikejc.org/news/articles/           404
# 26  https://new.bikejc.org/news/articles/2016-ward...           404
# 27  https://new.bikejc.org/news/articles/bike-jc-a...           404
# 28  https://new.bikejc.org/news/articles/citi-bike...           404
# 29  https://new.bikejc.org/news/articles/design-bi...           404
# 30  https://new.bikejc.org/news/articles/footbridg...           404
# 31  https://new.bikejc.org/news/articles/grand-str...           404
# 32  https://new.bikejc.org/news/articles/installat...           404
# 33  https://new.bikejc.org/news/articles/jersey-ci...           404
# 34  https://new.bikejc.org/news/articles/job-posti...           404
# 35        https://new.bikejc.org/news/media-coverage/           404
# 36                   https://new.bikejc.org/projects/           404
# 37        https://new.bikejc.org/projects/bike-lanes/           404
# 38        https://new.bikejc.org/projects/bike-racks/           404
# 39        https://new.bikejc.org/projects/bike-share/           404
# 40               https://new.bikejc.org/projects/gsv/           404
# 41                        https://new.bikejc.org/qrs/           404
# 42                  https://new.bikejc.org/resources/           404
# 43  https://new.bikejc.org/resources/national-bike...           404
# 44       https://new.bikejc.org/resources/rules-road/           404
# 45     https://new.bikejc.org/resources/useful-links/           404
# 46                    https://new.bikejc.org/support/           404
# 47  https://new.bikejc.org/support/cool-swag-cool-...           404
# 48             https://new.bikejc.org/support/donate/           404
# 49           https://new.bikejc.org/support/sponsors/           404
# 50          https://new.bikejc.org/support/volunteer/           404
# 51                   https://new.bikejc.org/thankyou/           404
# 52                  https://new.bikejc.org/ward-tour/           200
# 53             https://new.bikejc.org/ward-tour/2022/           200
# 54        https://new.bikejc.org/ward-tour/2022/faqs/           200
# 55  https://new.bikejc.org/ward-tour/2022/finish-l...           200
# 56       https://new.bikejc.org/ward-tour/2022/route/           200
# 57    https://new.bikejc.org/ward-tour/2022/sponsors/           200
# 58   https://new.bikejc.org/ward-tour/2022/volunteer/           200
# 59              https://new.bikejc.org/ward-tour/faq/           200

# %% [markdown]
# ### Write to "Pages" sheet:

# %%
spread.df_to_sheet(pages, index=False, sheet='Pages', replace=True)

# %% [markdown]
# ## Load [`redirects.json`](https://github.com/bikejc/bikejc.github.io/blob/main/redirects.json)
# This file contains "dynamic" redirects.
#
# The site build process calls [`write-redirects.js`](https://github.com/bikejc/bikejc.github.io/blob/main/write-redirects.js), which generates HTML files that look like:
# ```html
# <meta http-equiv=Refresh content="0; url=https://bikejc.regfox.com/ward-tour-2023?t=ref-wrd" />
# ```
#
# In Wix, we'll probably just make these permanent (301) redirects (though it was nice to be able to arbitrariliy change them, with the current setup…)

# %%
with open('redirects.json', 'r') as f:
    dyn_redirs = json.load(f)
dyn_redirs = DF([ dict(src=src, dst=dst) for src, dst in dyn_redirs.items() ])
dyn_redirs
# Out:
#                                                   src  \
# 0                                               /bbsu
# 1                                              /bbsuf
# 2                                         /bergen-pbl
# 3                       /events/jersey-city-ward-tour
# 4             /events/jersey-city-ward-tour/volunteer
# 5       /events/jersey-city-ward-tour/ward-tour-route
# 6   /events/jersey-city-ward-tour/finish-line-fest...
# 7    /events/jersey-city-ward-tour/ward-tour-sponsors
# 8                                                 /wt
# 9                                             /wt/faq
# 10                                           /wt/palm
# 11                                            /wt/reg
# 12                                       /wt/register
# 13                                      /wardtour/faq
# 14       /events/jersey-city-ward-tour/ward-tour-faqs
# 15                                /ward-tour/register
# 16                                 /wardtour/register
# 17                                /ward-tour/citibike
# 18                                                /bb
# 19                                            /bb/map
# 20                                         /bb/signup
# 21                                           /bikebus
# 22                                    /bikebus/waiver
# 23                                   /bike-bus/waiver
# 24                                       /bikebus/map
# 25                                    /bikebus/signup
# 26                                   /bikebus/sign-up
# 27                                   /bike-bus/signup
# 28                                  /bike-bus/sign-up
# 29                                           /sponsor
#
#                                                   dst
# 0   mailto:bikebus@bikejc.org?subject=Sign%20up&bo...
# 1                                    /bike-bus/signup
# 2   https://actionnetwork.org/petitions/build-a-be...
# 3                                          /ward-tour
# 4                           /ward-tour/2022/volunteer
# 5                     /ward-tour/2022/ward-tour-route
# 6                /ward-tour/2022/finish-line-festival
# 7                  /ward-tour/2022/ward-tour-sponsors
# 8                                          /ward-tour
# 9                                      /ward-tour/faq
# 10  https://bikejc.regfox.com/ward-tour-2023?t=pal...
# 11  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 12  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 13                                     /ward-tour/faq
# 14                               /ward-tour/2022/faqs
# 15  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 16  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 17  https://docs.google.com/forms/d/e/1FAIpQLSeQQ4...
# 18                                          /bike-bus
# 19                                      /bike-bus/map
# 20                                   /bike-bus/signup
# 21                                          /bike-bus
# 22  https://na4.documents.adobe.com/public/esignWi...
# 23  https://na4.documents.adobe.com/public/esignWi...
# 24                                      /bike-bus/map
# 25  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 26  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 27  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 28  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 29                 /ward-tour-2023-sponsor-packet.pdf

# %% [markdown]
# ### Create Wix-compatible redirects sheet
# - Combine static (`<page>` → `<page>/` redirects computed previously) and dynamic (`redirects.json`) redirects
# - Rename columns to match Wix's desired import format

# %%
stat_redirs = redirects.apply(lambda r: dict(src=f'/{r.path}', dst=f'/{r.dst}'), axis=1).apply(Series)
wix_redirs = concat([ dyn_redirs, stat_redirs ]).rename(columns={
    'src': 'Old URL',
    'dst': 'New URL',
})
wix_redirs
# Out:
#                                               Old URL  \
# 0                                               /bbsu
# 1                                              /bbsuf
# 2                                         /bergen-pbl
# 3                       /events/jersey-city-ward-tour
# 4             /events/jersey-city-ward-tour/volunteer
# 5       /events/jersey-city-ward-tour/ward-tour-route
# 6   /events/jersey-city-ward-tour/finish-line-fest...
# 7    /events/jersey-city-ward-tour/ward-tour-sponsors
# 8                                                 /wt
# 9                                             /wt/faq
# 10                                           /wt/palm
# 11                                            /wt/reg
# 12                                       /wt/register
# 13                                      /wardtour/faq
# 14       /events/jersey-city-ward-tour/ward-tour-faqs
# 15                                /ward-tour/register
# 16                                 /wardtour/register
# 17                                /ward-tour/citibike
# 18                                                /bb
# 19                                            /bb/map
# 20                                         /bb/signup
# 21                                           /bikebus
# 22                                    /bikebus/waiver
# 23                                   /bike-bus/waiver
# 24                                       /bikebus/map
# 25                                    /bikebus/signup
# 26                                   /bikebus/sign-up
# 27                                   /bike-bus/signup
# 28                                  /bike-bus/sign-up
# 29                                           /sponsor
# 14                               /about/board-members
# 15                                    /about/founding
# 16                                     /about/history
# 18                      /about/non-profit-information
# 19                                /bike-bus/aqua-line
# 20                                /bike-bus/blue-line
# 21                                /bike-bus/gold-line
# 22                               /bike-bus/green-line
# 25                                      /bike-bus/map
# 26                              /bike-bus/orange-line
# 27                                /bike-bus/pink-line
# 28                              /bike-bus/purple-line
# 29                                 /bike-bus/red-line
# 30                              /bike-bus/silver-line
# 31                                /bike-bus/teal-line
# 32                              /bike-bus/yellow-line
# 33                                        /contact-us
# 34                 /events/bike-jcast/bike-jcast-2017
# 36                                   /events/calendar
# 39        /news/articles/2016-ward-tour-press-release
# 40  /news/articles/bike-jc-awarded-jersey-city-gre...
# 41            /news/articles/citi-bike-jc-rebalancing
# 42  /news/articles/design-bike-jcs-7th-annual-ward...
# 43  /news/articles/footbridge-liberty-state-park-a...
# 44  /news/articles/grand-street-vision-protected-b...
# 46  /news/articles/installation-jersey-citys-new-b...
# 47  /news/articles/jersey-citys-first-permanent-bi...
# 48   /news/articles/job-posting-contract-grant-writer
# 50                               /news/media-coverage
# 51                               /projects/bike-lanes
# 52                               /projects/bike-racks
# 53                               /projects/bike-share
# 54                                      /projects/gsv
# 57                                               /qrs
# 59                  /resources/national-bike-registry
# 60                              /resources/rules-road
# 62                            /resources/useful-links
# 63                     /support/cool-swag-cool-bikers
# 64                                    /support/donate
# 66                                  /support/sponsors
# 67                                 /support/volunteer
# 68                                          /thankyou
# 69                               /ward-tour/2022/faqs
# 70               /ward-tour/2022/finish-line-festival
# 72                              /ward-tour/2022/route
# 74                           /ward-tour/2022/sponsors
# 75                          /ward-tour/2022/volunteer
# 76                                     /ward-tour/faq
#
#                                               New URL
# 0   mailto:bikebus@bikejc.org?subject=Sign%20up&bo...
# 1                                    /bike-bus/signup
# 2   https://actionnetwork.org/petitions/build-a-be...
# 3                                          /ward-tour
# 4                           /ward-tour/2022/volunteer
# 5                     /ward-tour/2022/ward-tour-route
# 6                /ward-tour/2022/finish-line-festival
# 7                  /ward-tour/2022/ward-tour-sponsors
# 8                                          /ward-tour
# 9                                      /ward-tour/faq
# 10  https://bikejc.regfox.com/ward-tour-2023?t=pal...
# 11  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 12  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 13                                     /ward-tour/faq
# 14                               /ward-tour/2022/faqs
# 15  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 16  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 17  https://docs.google.com/forms/d/e/1FAIpQLSeQQ4...
# 18                                          /bike-bus
# 19                                      /bike-bus/map
# 20                                   /bike-bus/signup
# 21                                          /bike-bus
# 22  https://na4.documents.adobe.com/public/esignWi...
# 23  https://na4.documents.adobe.com/public/esignWi...
# 24                                      /bike-bus/map
# 25  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 26  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 27  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 28  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 29                 /ward-tour-2023-sponsor-packet.pdf
# 14                              /about/board-members/
# 15                                   /about/founding/
# 16                                    /about/history/
# 18                     /about/non-profit-information/
# 19                               /bike-bus/aqua-line/
# 20                               /bike-bus/blue-line/
# 21                               /bike-bus/gold-line/
# 22                              /bike-bus/green-line/
# 25                                     /bike-bus/map/
# 26                             /bike-bus/orange-line/
# 27                               /bike-bus/pink-line/
# 28                             /bike-bus/purple-line/
# 29                                /bike-bus/red-line/
# 30                             /bike-bus/silver-line/
# 31                               /bike-bus/teal-line/
# 32                             /bike-bus/yellow-line/
# 33                                       /contact-us/
# 34                /events/bike-jcast/bike-jcast-2017/
# 36                                  /events/calendar/
# 39       /news/articles/2016-ward-tour-press-release/
# 40  /news/articles/bike-jc-awarded-jersey-city-gre...
# 41           /news/articles/citi-bike-jc-rebalancing/
# 42  /news/articles/design-bike-jcs-7th-annual-ward...
# 43  /news/articles/footbridge-liberty-state-park-a...
# 44  /news/articles/grand-street-vision-protected-b...
# 46  /news/articles/installation-jersey-citys-new-b...
# 47  /news/articles/jersey-citys-first-permanent-bi...
# 48  /news/articles/job-posting-contract-grant-writer/
# 50                              /news/media-coverage/
# 51                              /projects/bike-lanes/
# 52                              /projects/bike-racks/
# 53                              /projects/bike-share/
# 54                                     /projects/gsv/
# 57                                              /qrs/
# 59                 /resources/national-bike-registry/
# 60                             /resources/rules-road/
# 62                           /resources/useful-links/
# 63                    /support/cool-swag-cool-bikers/
# 64                                   /support/donate/
# 66                                 /support/sponsors/
# 67                                /support/volunteer/
# 68                                         /thankyou/
# 69                              /ward-tour/2022/faqs/
# 70              /ward-tour/2022/finish-line-festival/
# 72                             /ward-tour/2022/route/
# 74                          /ward-tour/2022/sponsors/
# 75                         /ward-tour/2022/volunteer/
# 76                                    /ward-tour/faq/

# %%
spread.df_to_sheet(wix_redirs, index=False, sheet='Page Redirects (for Wix import)', replace=True)

# %% [markdown]
# ## Check redirects' "src" and "dst" codes at [new.bikejc.org](https://new.bikejc.org)
# Combine them, write to ["Redirects" sheet](https://docs.google.com/spreadsheets/d/1dA7hR7kl74Hsvj0mBA9By3T3y3Fkd4jiwjsEWTeWRNw/edit#gid=1880431312)

# %% [markdown]
# ### Check redirects' "dst" codes

# %%
redir_dsts = wix_redirs['New URL']
redir_dsts = redir_dsts[redir_dsts.str.startswith('/')].drop_duplicates()
redir_dsts
# Out:
# 1                                      /bike-bus/signup
# 3                                            /ward-tour
# 4                             /ward-tour/2022/volunteer
# 5                       /ward-tour/2022/ward-tour-route
# 6                  /ward-tour/2022/finish-line-festival
# 7                    /ward-tour/2022/ward-tour-sponsors
# 9                                        /ward-tour/faq
# 14                                 /ward-tour/2022/faqs
# 18                                            /bike-bus
# 19                                        /bike-bus/map
# 29                   /ward-tour-2023-sponsor-packet.pdf
# 14                                /about/board-members/
# 15                                     /about/founding/
# 16                                      /about/history/
# 18                       /about/non-profit-information/
# 19                                 /bike-bus/aqua-line/
# 20                                 /bike-bus/blue-line/
# 21                                 /bike-bus/gold-line/
# 22                                /bike-bus/green-line/
# 25                                       /bike-bus/map/
# 26                               /bike-bus/orange-line/
# 27                                 /bike-bus/pink-line/
# 28                               /bike-bus/purple-line/
# 29                                  /bike-bus/red-line/
# 30                               /bike-bus/silver-line/
# 31                                 /bike-bus/teal-line/
# 32                               /bike-bus/yellow-line/
# 33                                         /contact-us/
# 34                  /events/bike-jcast/bike-jcast-2017/
# 36                                    /events/calendar/
# 39         /news/articles/2016-ward-tour-press-release/
# 40    /news/articles/bike-jc-awarded-jersey-city-gre...
# 41             /news/articles/citi-bike-jc-rebalancing/
# 42    /news/articles/design-bike-jcs-7th-annual-ward...
# 43    /news/articles/footbridge-liberty-state-park-a...
# 44    /news/articles/grand-street-vision-protected-b...
# 46    /news/articles/installation-jersey-citys-new-b...
# 47    /news/articles/jersey-citys-first-permanent-bi...
# 48    /news/articles/job-posting-contract-grant-writer/
# 50                                /news/media-coverage/
# 51                                /projects/bike-lanes/
# 52                                /projects/bike-racks/
# 53                                /projects/bike-share/
# 54                                       /projects/gsv/
# 57                                                /qrs/
# 59                   /resources/national-bike-registry/
# 60                               /resources/rules-road/
# 62                             /resources/useful-links/
# 63                      /support/cool-swag-cool-bikers/
# 64                                     /support/donate/
# 66                                   /support/sponsors/
# 67                                  /support/volunteer/
# 68                                           /thankyou/
# 69                                /ward-tour/2022/faqs/
# 70                /ward-tour/2022/finish-line-festival/
# 72                               /ward-tour/2022/route/
# 74                            /ward-tour/2022/sponsors/
# 75                           /ward-tour/2022/volunteer/
# 76                                      /ward-tour/faq/
# Name: New URL, dtype: object

# %%
# %%time
new_url_dst_codes = http_head_page_codes(redir_dsts, domain=new_domain)
new_url_dst_codes
# Out:
#                                                  path  code  dst
# 1                                    /bike-bus/signup   200  NaN
# 3                                          /ward-tour   200  NaN
# 4                           /ward-tour/2022/volunteer   200  NaN
# 5                     /ward-tour/2022/ward-tour-route   200  NaN
# 6                /ward-tour/2022/finish-line-festival   200  NaN
# 7                  /ward-tour/2022/ward-tour-sponsors   200  NaN
# 9                                      /ward-tour/faq   200  NaN
# 14                               /ward-tour/2022/faqs   200  NaN
# 18                                          /bike-bus   200  NaN
# 19                                      /bike-bus/map   200  NaN
# 29                 /ward-tour-2023-sponsor-packet.pdf   404  NaN
# 14                              /about/board-members/   200  NaN
# 15                                   /about/founding/   200  NaN
# 16                                    /about/history/   200  NaN
# 18                     /about/non-profit-information/   200  NaN
# 19                               /bike-bus/aqua-line/   200  NaN
# 20                               /bike-bus/blue-line/   200  NaN
# 21                               /bike-bus/gold-line/   200  NaN
# 22                              /bike-bus/green-line/   200  NaN
# 25                                     /bike-bus/map/   200  NaN
# 26                             /bike-bus/orange-line/   200  NaN
# 27                               /bike-bus/pink-line/   200  NaN
# 28                             /bike-bus/purple-line/   200  NaN
# 29                                /bike-bus/red-line/   200  NaN
# 30                             /bike-bus/silver-line/   200  NaN
# 31                               /bike-bus/teal-line/   200  NaN
# 32                             /bike-bus/yellow-line/   200  NaN
# 33                                       /contact-us/   404  NaN
# 34                /events/bike-jcast/bike-jcast-2017/   200  NaN
# 36                                  /events/calendar/   200  NaN
# 39       /news/articles/2016-ward-tour-press-release/   404  NaN
# 40  /news/articles/bike-jc-awarded-jersey-city-gre...   404  NaN
# 41           /news/articles/citi-bike-jc-rebalancing/   404  NaN
# 42  /news/articles/design-bike-jcs-7th-annual-ward...   404  NaN
# 43  /news/articles/footbridge-liberty-state-park-a...   404  NaN
# 44  /news/articles/grand-street-vision-protected-b...   404  NaN
# 46  /news/articles/installation-jersey-citys-new-b...   404  NaN
# 47  /news/articles/jersey-citys-first-permanent-bi...   404  NaN
# 48  /news/articles/job-posting-contract-grant-writer/   404  NaN
# 50                              /news/media-coverage/   404  NaN
# 51                              /projects/bike-lanes/   404  NaN
# 52                              /projects/bike-racks/   404  NaN
# 53                              /projects/bike-share/   404  NaN
# 54                                     /projects/gsv/   404  NaN
# 57                                              /qrs/   404  NaN
# 59                 /resources/national-bike-registry/   404  NaN
# 60                             /resources/rules-road/   404  NaN
# 62                           /resources/useful-links/   404  NaN
# 63                    /support/cool-swag-cool-bikers/   404  NaN
# 64                                   /support/donate/   404  NaN
# 66                                 /support/sponsors/   404  NaN
# 67                                /support/volunteer/   404  NaN
# 68                                         /thankyou/   404  NaN
# 69                              /ward-tour/2022/faqs/   200  NaN
# 70              /ward-tour/2022/finish-line-festival/   200  NaN
# 72                             /ward-tour/2022/route/   200  NaN
# 74                          /ward-tour/2022/sponsors/   200  NaN
# 75                         /ward-tour/2022/volunteer/   200  NaN
# 76                                    /ward-tour/faq/   200  NaN

# %%
new_url_dsts = sxs(
    new_url_dst_codes.dropna(axis=1),
    new_url_dst_codes.path.apply(lambda p: f'{new_page_prefix}{p[1:]}').rename('new_url'),
)
new_url_dsts
# Out:
#                                                  path  code  \
# 1                                    /bike-bus/signup   200
# 3                                          /ward-tour   200
# 4                           /ward-tour/2022/volunteer   200
# 5                     /ward-tour/2022/ward-tour-route   200
# 6                /ward-tour/2022/finish-line-festival   200
# 7                  /ward-tour/2022/ward-tour-sponsors   200
# 9                                      /ward-tour/faq   200
# 14                               /ward-tour/2022/faqs   200
# 18                                          /bike-bus   200
# 19                                      /bike-bus/map   200
# 29                 /ward-tour-2023-sponsor-packet.pdf   404
# 14                              /about/board-members/   200
# 15                                   /about/founding/   200
# 16                                    /about/history/   200
# 18                     /about/non-profit-information/   200
# 19                               /bike-bus/aqua-line/   200
# 20                               /bike-bus/blue-line/   200
# 21                               /bike-bus/gold-line/   200
# 22                              /bike-bus/green-line/   200
# 25                                     /bike-bus/map/   200
# 26                             /bike-bus/orange-line/   200
# 27                               /bike-bus/pink-line/   200
# 28                             /bike-bus/purple-line/   200
# 29                                /bike-bus/red-line/   200
# 30                             /bike-bus/silver-line/   200
# 31                               /bike-bus/teal-line/   200
# 32                             /bike-bus/yellow-line/   200
# 33                                       /contact-us/   404
# 34                /events/bike-jcast/bike-jcast-2017/   200
# 36                                  /events/calendar/   200
# 39       /news/articles/2016-ward-tour-press-release/   404
# 40  /news/articles/bike-jc-awarded-jersey-city-gre...   404
# 41           /news/articles/citi-bike-jc-rebalancing/   404
# 42  /news/articles/design-bike-jcs-7th-annual-ward...   404
# 43  /news/articles/footbridge-liberty-state-park-a...   404
# 44  /news/articles/grand-street-vision-protected-b...   404
# 46  /news/articles/installation-jersey-citys-new-b...   404
# 47  /news/articles/jersey-citys-first-permanent-bi...   404
# 48  /news/articles/job-posting-contract-grant-writer/   404
# 50                              /news/media-coverage/   404
# 51                              /projects/bike-lanes/   404
# 52                              /projects/bike-racks/   404
# 53                              /projects/bike-share/   404
# 54                                     /projects/gsv/   404
# 57                                              /qrs/   404
# 59                 /resources/national-bike-registry/   404
# 60                             /resources/rules-road/   404
# 62                           /resources/useful-links/   404
# 63                    /support/cool-swag-cool-bikers/   404
# 64                                   /support/donate/   404
# 66                                 /support/sponsors/   404
# 67                                /support/volunteer/   404
# 68                                         /thankyou/   404
# 69                              /ward-tour/2022/faqs/   200
# 70              /ward-tour/2022/finish-line-festival/   200
# 72                             /ward-tour/2022/route/   200
# 74                          /ward-tour/2022/sponsors/   200
# 75                         /ward-tour/2022/volunteer/   200
# 76                                    /ward-tour/faq/   200
#
#                                               new_url
# 1              https://new.bikejc.org/bike-bus/signup
# 3                    https://new.bikejc.org/ward-tour
# 4     https://new.bikejc.org/ward-tour/2022/volunteer
# 5   https://new.bikejc.org/ward-tour/2022/ward-tou...
# 6   https://new.bikejc.org/ward-tour/2022/finish-l...
# 7   https://new.bikejc.org/ward-tour/2022/ward-tou...
# 9                https://new.bikejc.org/ward-tour/faq
# 14         https://new.bikejc.org/ward-tour/2022/faqs
# 18                    https://new.bikejc.org/bike-bus
# 19                https://new.bikejc.org/bike-bus/map
# 29  https://new.bikejc.org/ward-tour-2023-sponsor-...
# 14        https://new.bikejc.org/about/board-members/
# 15             https://new.bikejc.org/about/founding/
# 16              https://new.bikejc.org/about/history/
# 18  https://new.bikejc.org/about/non-profit-inform...
# 19         https://new.bikejc.org/bike-bus/aqua-line/
# 20         https://new.bikejc.org/bike-bus/blue-line/
# 21         https://new.bikejc.org/bike-bus/gold-line/
# 22        https://new.bikejc.org/bike-bus/green-line/
# 25               https://new.bikejc.org/bike-bus/map/
# 26       https://new.bikejc.org/bike-bus/orange-line/
# 27         https://new.bikejc.org/bike-bus/pink-line/
# 28       https://new.bikejc.org/bike-bus/purple-line/
# 29          https://new.bikejc.org/bike-bus/red-line/
# 30       https://new.bikejc.org/bike-bus/silver-line/
# 31         https://new.bikejc.org/bike-bus/teal-line/
# 32       https://new.bikejc.org/bike-bus/yellow-line/
# 33                 https://new.bikejc.org/contact-us/
# 34  https://new.bikejc.org/events/bike-jcast/bike-...
# 36            https://new.bikejc.org/events/calendar/
# 39  https://new.bikejc.org/news/articles/2016-ward...
# 40  https://new.bikejc.org/news/articles/bike-jc-a...
# 41  https://new.bikejc.org/news/articles/citi-bike...
# 42  https://new.bikejc.org/news/articles/design-bi...
# 43  https://new.bikejc.org/news/articles/footbridg...
# 44  https://new.bikejc.org/news/articles/grand-str...
# 46  https://new.bikejc.org/news/articles/installat...
# 47  https://new.bikejc.org/news/articles/jersey-ci...
# 48  https://new.bikejc.org/news/articles/job-posti...
# 50        https://new.bikejc.org/news/media-coverage/
# 51        https://new.bikejc.org/projects/bike-lanes/
# 52        https://new.bikejc.org/projects/bike-racks/
# 53        https://new.bikejc.org/projects/bike-share/
# 54               https://new.bikejc.org/projects/gsv/
# 57                        https://new.bikejc.org/qrs/
# 59  https://new.bikejc.org/resources/national-bike...
# 60       https://new.bikejc.org/resources/rules-road/
# 62     https://new.bikejc.org/resources/useful-links/
# 63  https://new.bikejc.org/support/cool-swag-cool-...
# 64             https://new.bikejc.org/support/donate/
# 66           https://new.bikejc.org/support/sponsors/
# 67          https://new.bikejc.org/support/volunteer/
# 68                   https://new.bikejc.org/thankyou/
# 69        https://new.bikejc.org/ward-tour/2022/faqs/
# 70  https://new.bikejc.org/ward-tour/2022/finish-l...
# 72       https://new.bikejc.org/ward-tour/2022/route/
# 74    https://new.bikejc.org/ward-tour/2022/sponsors/
# 75   https://new.bikejc.org/ward-tour/2022/volunteer/
# 76              https://new.bikejc.org/ward-tour/faq/

# %% [markdown]
# ### Check redirects' "src" codes

# %%
redir_srcs = wix_redirs['Old URL']
redir_srcs
# Out:
# 0                                                 /bbsu
# 1                                                /bbsuf
# 2                                           /bergen-pbl
# 3                         /events/jersey-city-ward-tour
# 4               /events/jersey-city-ward-tour/volunteer
# 5         /events/jersey-city-ward-tour/ward-tour-route
# 6     /events/jersey-city-ward-tour/finish-line-fest...
# 7      /events/jersey-city-ward-tour/ward-tour-sponsors
# 8                                                   /wt
# 9                                               /wt/faq
# 10                                             /wt/palm
# 11                                              /wt/reg
# 12                                         /wt/register
# 13                                        /wardtour/faq
# 14         /events/jersey-city-ward-tour/ward-tour-faqs
# 15                                  /ward-tour/register
# 16                                   /wardtour/register
# 17                                  /ward-tour/citibike
# 18                                                  /bb
# 19                                              /bb/map
# 20                                           /bb/signup
# 21                                             /bikebus
# 22                                      /bikebus/waiver
# 23                                     /bike-bus/waiver
# 24                                         /bikebus/map
# 25                                      /bikebus/signup
# 26                                     /bikebus/sign-up
# 27                                     /bike-bus/signup
# 28                                    /bike-bus/sign-up
# 29                                             /sponsor
# 14                                 /about/board-members
# 15                                      /about/founding
# 16                                       /about/history
# 18                        /about/non-profit-information
# 19                                  /bike-bus/aqua-line
# 20                                  /bike-bus/blue-line
# 21                                  /bike-bus/gold-line
# 22                                 /bike-bus/green-line
# 25                                        /bike-bus/map
# 26                                /bike-bus/orange-line
# 27                                  /bike-bus/pink-line
# 28                                /bike-bus/purple-line
# 29                                   /bike-bus/red-line
# 30                                /bike-bus/silver-line
# 31                                  /bike-bus/teal-line
# 32                                /bike-bus/yellow-line
# 33                                          /contact-us
# 34                   /events/bike-jcast/bike-jcast-2017
# 36                                     /events/calendar
# 39          /news/articles/2016-ward-tour-press-release
# 40    /news/articles/bike-jc-awarded-jersey-city-gre...
# 41              /news/articles/citi-bike-jc-rebalancing
# 42    /news/articles/design-bike-jcs-7th-annual-ward...
# 43    /news/articles/footbridge-liberty-state-park-a...
# 44    /news/articles/grand-street-vision-protected-b...
# 46    /news/articles/installation-jersey-citys-new-b...
# 47    /news/articles/jersey-citys-first-permanent-bi...
# 48     /news/articles/job-posting-contract-grant-writer
# 50                                 /news/media-coverage
# 51                                 /projects/bike-lanes
# 52                                 /projects/bike-racks
# 53                                 /projects/bike-share
# 54                                        /projects/gsv
# 57                                                 /qrs
# 59                    /resources/national-bike-registry
# 60                                /resources/rules-road
# 62                              /resources/useful-links
# 63                       /support/cool-swag-cool-bikers
# 64                                      /support/donate
# 66                                    /support/sponsors
# 67                                   /support/volunteer
# 68                                            /thankyou
# 69                                 /ward-tour/2022/faqs
# 70                 /ward-tour/2022/finish-line-festival
# 72                                /ward-tour/2022/route
# 74                             /ward-tour/2022/sponsors
# 75                            /ward-tour/2022/volunteer
# 76                                       /ward-tour/faq
# Name: Old URL, dtype: object

# %%
# %%time
new_url_src_codes = http_head_page_codes(redir_srcs, domain=new_domain)
new_url_src_codes
# Out:
#                                                  path  code  dst
# 0                                               /bbsu   404  NaN
# 1                                              /bbsuf   404  NaN
# 2                                         /bergen-pbl   404  NaN
# 3                       /events/jersey-city-ward-tour   200  NaN
# 4             /events/jersey-city-ward-tour/volunteer   200  NaN
# 5       /events/jersey-city-ward-tour/ward-tour-route   200  NaN
# 6   /events/jersey-city-ward-tour/finish-line-fest...   200  NaN
# 7    /events/jersey-city-ward-tour/ward-tour-sponsors   200  NaN
# 8                                                 /wt   404  NaN
# 9                                             /wt/faq   404  NaN
# 10                                           /wt/palm   404  NaN
# 11                                            /wt/reg   404  NaN
# 12                                       /wt/register   404  NaN
# 13                                      /wardtour/faq   404  NaN
# 14       /events/jersey-city-ward-tour/ward-tour-faqs   200  NaN
# 15                                /ward-tour/register   200  NaN
# 16                                 /wardtour/register   404  NaN
# 17                                /ward-tour/citibike   200  NaN
# 18                                                /bb   404  NaN
# 19                                            /bb/map   404  NaN
# 20                                         /bb/signup   404  NaN
# 21                                           /bikebus   404  NaN
# 22                                    /bikebus/waiver   404  NaN
# 23                                   /bike-bus/waiver   200  NaN
# 24                                       /bikebus/map   404  NaN
# 25                                    /bikebus/signup   404  NaN
# 26                                   /bikebus/sign-up   404  NaN
# 27                                   /bike-bus/signup   200  NaN
# 28                                  /bike-bus/sign-up   200  NaN
# 29                                           /sponsor   404  NaN
# 14                               /about/board-members   200  NaN
# 15                                    /about/founding   200  NaN
# 16                                     /about/history   200  NaN
# 18                      /about/non-profit-information   200  NaN
# 19                                /bike-bus/aqua-line   200  NaN
# 20                                /bike-bus/blue-line   200  NaN
# 21                                /bike-bus/gold-line   200  NaN
# 22                               /bike-bus/green-line   200  NaN
# 25                                      /bike-bus/map   200  NaN
# 26                              /bike-bus/orange-line   200  NaN
# 27                                /bike-bus/pink-line   200  NaN
# 28                              /bike-bus/purple-line   200  NaN
# 29                                 /bike-bus/red-line   200  NaN
# 30                              /bike-bus/silver-line   200  NaN
# 31                                /bike-bus/teal-line   200  NaN
# 32                              /bike-bus/yellow-line   200  NaN
# 33                                        /contact-us   404  NaN
# 34                 /events/bike-jcast/bike-jcast-2017   200  NaN
# 36                                   /events/calendar   200  NaN
# 39        /news/articles/2016-ward-tour-press-release   404  NaN
# 40  /news/articles/bike-jc-awarded-jersey-city-gre...   404  NaN
# 41            /news/articles/citi-bike-jc-rebalancing   404  NaN
# 42  /news/articles/design-bike-jcs-7th-annual-ward...   404  NaN
# 43  /news/articles/footbridge-liberty-state-park-a...   404  NaN
# 44  /news/articles/grand-street-vision-protected-b...   404  NaN
# 46  /news/articles/installation-jersey-citys-new-b...   404  NaN
# 47  /news/articles/jersey-citys-first-permanent-bi...   404  NaN
# 48   /news/articles/job-posting-contract-grant-writer   404  NaN
# 50                               /news/media-coverage   404  NaN
# 51                               /projects/bike-lanes   404  NaN
# 52                               /projects/bike-racks   404  NaN
# 53                               /projects/bike-share   404  NaN
# 54                                      /projects/gsv   404  NaN
# 57                                               /qrs   404  NaN
# 59                  /resources/national-bike-registry   404  NaN
# 60                              /resources/rules-road   404  NaN
# 62                            /resources/useful-links   404  NaN
# 63                     /support/cool-swag-cool-bikers   404  NaN
# 64                                    /support/donate   404  NaN
# 66                                  /support/sponsors   404  NaN
# 67                                 /support/volunteer   404  NaN
# 68                                          /thankyou   404  NaN
# 69                               /ward-tour/2022/faqs   200  NaN
# 70               /ward-tour/2022/finish-line-festival   200  NaN
# 72                              /ward-tour/2022/route   200  NaN
# 74                           /ward-tour/2022/sponsors   200  NaN
# 75                          /ward-tour/2022/volunteer   200  NaN
# 76                                     /ward-tour/faq   200  NaN

# %%
new_url_srcs = sxs(
    new_url_src_codes.dropna(axis=1),
    new_url_src_codes.path.apply(lambda p: f'{new_page_prefix}{p[1:]}').rename('new_url'),
)
new_url_srcs
# Out:
#                                                  path  code  \
# 0                                               /bbsu   404
# 1                                              /bbsuf   404
# 2                                         /bergen-pbl   404
# 3                       /events/jersey-city-ward-tour   200
# 4             /events/jersey-city-ward-tour/volunteer   200
# 5       /events/jersey-city-ward-tour/ward-tour-route   200
# 6   /events/jersey-city-ward-tour/finish-line-fest...   200
# 7    /events/jersey-city-ward-tour/ward-tour-sponsors   200
# 8                                                 /wt   404
# 9                                             /wt/faq   404
# 10                                           /wt/palm   404
# 11                                            /wt/reg   404
# 12                                       /wt/register   404
# 13                                      /wardtour/faq   404
# 14       /events/jersey-city-ward-tour/ward-tour-faqs   200
# 15                                /ward-tour/register   200
# 16                                 /wardtour/register   404
# 17                                /ward-tour/citibike   200
# 18                                                /bb   404
# 19                                            /bb/map   404
# 20                                         /bb/signup   404
# 21                                           /bikebus   404
# 22                                    /bikebus/waiver   404
# 23                                   /bike-bus/waiver   200
# 24                                       /bikebus/map   404
# 25                                    /bikebus/signup   404
# 26                                   /bikebus/sign-up   404
# 27                                   /bike-bus/signup   200
# 28                                  /bike-bus/sign-up   200
# 29                                           /sponsor   404
# 14                               /about/board-members   200
# 15                                    /about/founding   200
# 16                                     /about/history   200
# 18                      /about/non-profit-information   200
# 19                                /bike-bus/aqua-line   200
# 20                                /bike-bus/blue-line   200
# 21                                /bike-bus/gold-line   200
# 22                               /bike-bus/green-line   200
# 25                                      /bike-bus/map   200
# 26                              /bike-bus/orange-line   200
# 27                                /bike-bus/pink-line   200
# 28                              /bike-bus/purple-line   200
# 29                                 /bike-bus/red-line   200
# 30                              /bike-bus/silver-line   200
# 31                                /bike-bus/teal-line   200
# 32                              /bike-bus/yellow-line   200
# 33                                        /contact-us   404
# 34                 /events/bike-jcast/bike-jcast-2017   200
# 36                                   /events/calendar   200
# 39        /news/articles/2016-ward-tour-press-release   404
# 40  /news/articles/bike-jc-awarded-jersey-city-gre...   404
# 41            /news/articles/citi-bike-jc-rebalancing   404
# 42  /news/articles/design-bike-jcs-7th-annual-ward...   404
# 43  /news/articles/footbridge-liberty-state-park-a...   404
# 44  /news/articles/grand-street-vision-protected-b...   404
# 46  /news/articles/installation-jersey-citys-new-b...   404
# 47  /news/articles/jersey-citys-first-permanent-bi...   404
# 48   /news/articles/job-posting-contract-grant-writer   404
# 50                               /news/media-coverage   404
# 51                               /projects/bike-lanes   404
# 52                               /projects/bike-racks   404
# 53                               /projects/bike-share   404
# 54                                      /projects/gsv   404
# 57                                               /qrs   404
# 59                  /resources/national-bike-registry   404
# 60                              /resources/rules-road   404
# 62                            /resources/useful-links   404
# 63                     /support/cool-swag-cool-bikers   404
# 64                                    /support/donate   404
# 66                                  /support/sponsors   404
# 67                                 /support/volunteer   404
# 68                                          /thankyou   404
# 69                               /ward-tour/2022/faqs   200
# 70               /ward-tour/2022/finish-line-festival   200
# 72                              /ward-tour/2022/route   200
# 74                           /ward-tour/2022/sponsors   200
# 75                          /ward-tour/2022/volunteer   200
# 76                                     /ward-tour/faq   200
#
#                                               new_url
# 0                         https://new.bikejc.org/bbsu
# 1                        https://new.bikejc.org/bbsuf
# 2                   https://new.bikejc.org/bergen-pbl
# 3   https://new.bikejc.org/events/jersey-city-ward...
# 4   https://new.bikejc.org/events/jersey-city-ward...
# 5   https://new.bikejc.org/events/jersey-city-ward...
# 6   https://new.bikejc.org/events/jersey-city-ward...
# 7   https://new.bikejc.org/events/jersey-city-ward...
# 8                           https://new.bikejc.org/wt
# 9                       https://new.bikejc.org/wt/faq
# 10                     https://new.bikejc.org/wt/palm
# 11                      https://new.bikejc.org/wt/reg
# 12                 https://new.bikejc.org/wt/register
# 13                https://new.bikejc.org/wardtour/faq
# 14  https://new.bikejc.org/events/jersey-city-ward...
# 15          https://new.bikejc.org/ward-tour/register
# 16           https://new.bikejc.org/wardtour/register
# 17          https://new.bikejc.org/ward-tour/citibike
# 18                          https://new.bikejc.org/bb
# 19                      https://new.bikejc.org/bb/map
# 20                   https://new.bikejc.org/bb/signup
# 21                     https://new.bikejc.org/bikebus
# 22              https://new.bikejc.org/bikebus/waiver
# 23             https://new.bikejc.org/bike-bus/waiver
# 24                 https://new.bikejc.org/bikebus/map
# 25              https://new.bikejc.org/bikebus/signup
# 26             https://new.bikejc.org/bikebus/sign-up
# 27             https://new.bikejc.org/bike-bus/signup
# 28            https://new.bikejc.org/bike-bus/sign-up
# 29                     https://new.bikejc.org/sponsor
# 14         https://new.bikejc.org/about/board-members
# 15              https://new.bikejc.org/about/founding
# 16               https://new.bikejc.org/about/history
# 18  https://new.bikejc.org/about/non-profit-inform...
# 19          https://new.bikejc.org/bike-bus/aqua-line
# 20          https://new.bikejc.org/bike-bus/blue-line
# 21          https://new.bikejc.org/bike-bus/gold-line
# 22         https://new.bikejc.org/bike-bus/green-line
# 25                https://new.bikejc.org/bike-bus/map
# 26        https://new.bikejc.org/bike-bus/orange-line
# 27          https://new.bikejc.org/bike-bus/pink-line
# 28        https://new.bikejc.org/bike-bus/purple-line
# 29           https://new.bikejc.org/bike-bus/red-line
# 30        https://new.bikejc.org/bike-bus/silver-line
# 31          https://new.bikejc.org/bike-bus/teal-line
# 32        https://new.bikejc.org/bike-bus/yellow-line
# 33                  https://new.bikejc.org/contact-us
# 34  https://new.bikejc.org/events/bike-jcast/bike-...
# 36             https://new.bikejc.org/events/calendar
# 39  https://new.bikejc.org/news/articles/2016-ward...
# 40  https://new.bikejc.org/news/articles/bike-jc-a...
# 41  https://new.bikejc.org/news/articles/citi-bike...
# 42  https://new.bikejc.org/news/articles/design-bi...
# 43  https://new.bikejc.org/news/articles/footbridg...
# 44  https://new.bikejc.org/news/articles/grand-str...
# 46  https://new.bikejc.org/news/articles/installat...
# 47  https://new.bikejc.org/news/articles/jersey-ci...
# 48  https://new.bikejc.org/news/articles/job-posti...
# 50         https://new.bikejc.org/news/media-coverage
# 51         https://new.bikejc.org/projects/bike-lanes
# 52         https://new.bikejc.org/projects/bike-racks
# 53         https://new.bikejc.org/projects/bike-share
# 54                https://new.bikejc.org/projects/gsv
# 57                         https://new.bikejc.org/qrs
# 59  https://new.bikejc.org/resources/national-bike...
# 60        https://new.bikejc.org/resources/rules-road
# 62      https://new.bikejc.org/resources/useful-links
# 63  https://new.bikejc.org/support/cool-swag-cool-...
# 64              https://new.bikejc.org/support/donate
# 66            https://new.bikejc.org/support/sponsors
# 67           https://new.bikejc.org/support/volunteer
# 68                    https://new.bikejc.org/thankyou
# 69         https://new.bikejc.org/ward-tour/2022/faqs
# 70  https://new.bikejc.org/ward-tour/2022/finish-l...
# 72        https://new.bikejc.org/ward-tour/2022/route
# 74     https://new.bikejc.org/ward-tour/2022/sponsors
# 75    https://new.bikejc.org/ward-tour/2022/volunteer
# 76               https://new.bikejc.org/ward-tour/faq

# %% [markdown]
# ### Combine redirects' "src" and "dst" codes

# %%
all_redirs = (
    wix_redirs
    .rename(columns={
        'Old URL': 'src_path',
        'New URL': 'dst',
    })
    .merge(
        new_url_srcs.rename(columns={
            'path': 'src_path',
            'new_url': 'src_new_url',
            'code': 'src_new_code',
        }),
        how='left',
        on='src_path',
    )
)
all_redirs['src_cur_url'] = all_redirs.src_path.apply(lambda p: f'{page_prefix}{p[1:]}')
all_redirs = (
    all_redirs
    .merge(
        new_url_dsts.rename(columns={
            'path': 'dst',
            'new_url': 'dst_new_url',
            'code': 'dst_new_code',            
        }),
        how='left',
        on='dst',
    )
)
all_redirs['dst_new_code'] = all_redirs.dst_new_code.apply(lambda c: '' if isna(c) else str(int(c)))
all_redirs['dst_new_url'] = all_redirs['dst_new_url'].fillna('')
all_redirs = all_redirs[[ 'src_path', 'src_cur_url', 'src_new_url', 'src_new_code', 'dst', 'dst_new_url', 'dst_new_code', ]]
all_redirs
# Out:
#                                              src_path  \
# 0                                               /bbsu
# 1                                              /bbsuf
# 2                                         /bergen-pbl
# 3                       /events/jersey-city-ward-tour
# 4             /events/jersey-city-ward-tour/volunteer
# 5       /events/jersey-city-ward-tour/ward-tour-route
# 6   /events/jersey-city-ward-tour/finish-line-fest...
# 7    /events/jersey-city-ward-tour/ward-tour-sponsors
# 8                                                 /wt
# 9                                             /wt/faq
# 10                                           /wt/palm
# 11                                            /wt/reg
# 12                                       /wt/register
# 13                                      /wardtour/faq
# 14       /events/jersey-city-ward-tour/ward-tour-faqs
# 15                                /ward-tour/register
# 16                                 /wardtour/register
# 17                                /ward-tour/citibike
# 18                                                /bb
# 19                                            /bb/map
# 20                                         /bb/signup
# 21                                           /bikebus
# 22                                    /bikebus/waiver
# 23                                   /bike-bus/waiver
# 24                                       /bikebus/map
# 25                                    /bikebus/signup
# 26                                   /bikebus/sign-up
# 27                                   /bike-bus/signup
# 28                                  /bike-bus/sign-up
# 29                                           /sponsor
# 30                               /about/board-members
# 31                                    /about/founding
# 32                                     /about/history
# 33                      /about/non-profit-information
# 34                                /bike-bus/aqua-line
# 35                                /bike-bus/blue-line
# 36                                /bike-bus/gold-line
# 37                               /bike-bus/green-line
# 38                                      /bike-bus/map
# 39                              /bike-bus/orange-line
# 40                                /bike-bus/pink-line
# 41                              /bike-bus/purple-line
# 42                                 /bike-bus/red-line
# 43                              /bike-bus/silver-line
# 44                                /bike-bus/teal-line
# 45                              /bike-bus/yellow-line
# 46                                        /contact-us
# 47                 /events/bike-jcast/bike-jcast-2017
# 48                                   /events/calendar
# 49        /news/articles/2016-ward-tour-press-release
# 50  /news/articles/bike-jc-awarded-jersey-city-gre...
# 51            /news/articles/citi-bike-jc-rebalancing
# 52  /news/articles/design-bike-jcs-7th-annual-ward...
# 53  /news/articles/footbridge-liberty-state-park-a...
# 54  /news/articles/grand-street-vision-protected-b...
# 55  /news/articles/installation-jersey-citys-new-b...
# 56  /news/articles/jersey-citys-first-permanent-bi...
# 57   /news/articles/job-posting-contract-grant-writer
# 58                               /news/media-coverage
# 59                               /projects/bike-lanes
# 60                               /projects/bike-racks
# 61                               /projects/bike-share
# 62                                      /projects/gsv
# 63                                               /qrs
# 64                  /resources/national-bike-registry
# 65                              /resources/rules-road
# 66                            /resources/useful-links
# 67                     /support/cool-swag-cool-bikers
# 68                                    /support/donate
# 69                                  /support/sponsors
# 70                                 /support/volunteer
# 71                                          /thankyou
# 72                               /ward-tour/2022/faqs
# 73               /ward-tour/2022/finish-line-festival
# 74                              /ward-tour/2022/route
# 75                           /ward-tour/2022/sponsors
# 76                          /ward-tour/2022/volunteer
# 77                                     /ward-tour/faq
#
#                                           src_cur_url  \
# 0                             https://bikejc.org/bbsu
# 1                            https://bikejc.org/bbsuf
# 2                       https://bikejc.org/bergen-pbl
# 3     https://bikejc.org/events/jersey-city-ward-tour
# 4   https://bikejc.org/events/jersey-city-ward-tou...
# 5   https://bikejc.org/events/jersey-city-ward-tou...
# 6   https://bikejc.org/events/jersey-city-ward-tou...
# 7   https://bikejc.org/events/jersey-city-ward-tou...
# 8                               https://bikejc.org/wt
# 9                           https://bikejc.org/wt/faq
# 10                         https://bikejc.org/wt/palm
# 11                          https://bikejc.org/wt/reg
# 12                     https://bikejc.org/wt/register
# 13                    https://bikejc.org/wardtour/faq
# 14  https://bikejc.org/events/jersey-city-ward-tou...
# 15              https://bikejc.org/ward-tour/register
# 16               https://bikejc.org/wardtour/register
# 17              https://bikejc.org/ward-tour/citibike
# 18                              https://bikejc.org/bb
# 19                          https://bikejc.org/bb/map
# 20                       https://bikejc.org/bb/signup
# 21                         https://bikejc.org/bikebus
# 22                  https://bikejc.org/bikebus/waiver
# 23                 https://bikejc.org/bike-bus/waiver
# 24                     https://bikejc.org/bikebus/map
# 25                  https://bikejc.org/bikebus/signup
# 26                 https://bikejc.org/bikebus/sign-up
# 27                 https://bikejc.org/bike-bus/signup
# 28                https://bikejc.org/bike-bus/sign-up
# 29                         https://bikejc.org/sponsor
# 30             https://bikejc.org/about/board-members
# 31                  https://bikejc.org/about/founding
# 32                   https://bikejc.org/about/history
# 33    https://bikejc.org/about/non-profit-information
# 34              https://bikejc.org/bike-bus/aqua-line
# 35              https://bikejc.org/bike-bus/blue-line
# 36              https://bikejc.org/bike-bus/gold-line
# 37             https://bikejc.org/bike-bus/green-line
# 38                    https://bikejc.org/bike-bus/map
# 39            https://bikejc.org/bike-bus/orange-line
# 40              https://bikejc.org/bike-bus/pink-line
# 41            https://bikejc.org/bike-bus/purple-line
# 42               https://bikejc.org/bike-bus/red-line
# 43            https://bikejc.org/bike-bus/silver-line
# 44              https://bikejc.org/bike-bus/teal-line
# 45            https://bikejc.org/bike-bus/yellow-line
# 46                      https://bikejc.org/contact-us
# 47  https://bikejc.org/events/bike-jcast/bike-jcas...
# 48                 https://bikejc.org/events/calendar
# 49  https://bikejc.org/news/articles/2016-ward-tou...
# 50  https://bikejc.org/news/articles/bike-jc-award...
# 51  https://bikejc.org/news/articles/citi-bike-jc-...
# 52  https://bikejc.org/news/articles/design-bike-j...
# 53  https://bikejc.org/news/articles/footbridge-li...
# 54  https://bikejc.org/news/articles/grand-street-...
# 55  https://bikejc.org/news/articles/installation-...
# 56  https://bikejc.org/news/articles/jersey-citys-...
# 57  https://bikejc.org/news/articles/job-posting-c...
# 58             https://bikejc.org/news/media-coverage
# 59             https://bikejc.org/projects/bike-lanes
# 60             https://bikejc.org/projects/bike-racks
# 61             https://bikejc.org/projects/bike-share
# 62                    https://bikejc.org/projects/gsv
# 63                             https://bikejc.org/qrs
# 64  https://bikejc.org/resources/national-bike-reg...
# 65            https://bikejc.org/resources/rules-road
# 66          https://bikejc.org/resources/useful-links
# 67   https://bikejc.org/support/cool-swag-cool-bikers
# 68                  https://bikejc.org/support/donate
# 69                https://bikejc.org/support/sponsors
# 70               https://bikejc.org/support/volunteer
# 71                        https://bikejc.org/thankyou
# 72             https://bikejc.org/ward-tour/2022/faqs
# 73  https://bikejc.org/ward-tour/2022/finish-line-...
# 74            https://bikejc.org/ward-tour/2022/route
# 75         https://bikejc.org/ward-tour/2022/sponsors
# 76        https://bikejc.org/ward-tour/2022/volunteer
# 77                   https://bikejc.org/ward-tour/faq
#
#                                           src_new_url  src_new_code  \
# 0                         https://new.bikejc.org/bbsu           404
# 1                        https://new.bikejc.org/bbsuf           404
# 2                   https://new.bikejc.org/bergen-pbl           404
# 3   https://new.bikejc.org/events/jersey-city-ward...           200
# 4   https://new.bikejc.org/events/jersey-city-ward...           200
# 5   https://new.bikejc.org/events/jersey-city-ward...           200
# 6   https://new.bikejc.org/events/jersey-city-ward...           200
# 7   https://new.bikejc.org/events/jersey-city-ward...           200
# 8                           https://new.bikejc.org/wt           404
# 9                       https://new.bikejc.org/wt/faq           404
# 10                     https://new.bikejc.org/wt/palm           404
# 11                      https://new.bikejc.org/wt/reg           404
# 12                 https://new.bikejc.org/wt/register           404
# 13                https://new.bikejc.org/wardtour/faq           404
# 14  https://new.bikejc.org/events/jersey-city-ward...           200
# 15          https://new.bikejc.org/ward-tour/register           200
# 16           https://new.bikejc.org/wardtour/register           404
# 17          https://new.bikejc.org/ward-tour/citibike           200
# 18                          https://new.bikejc.org/bb           404
# 19                      https://new.bikejc.org/bb/map           404
# 20                   https://new.bikejc.org/bb/signup           404
# 21                     https://new.bikejc.org/bikebus           404
# 22              https://new.bikejc.org/bikebus/waiver           404
# 23             https://new.bikejc.org/bike-bus/waiver           200
# 24                 https://new.bikejc.org/bikebus/map           404
# 25              https://new.bikejc.org/bikebus/signup           404
# 26             https://new.bikejc.org/bikebus/sign-up           404
# 27             https://new.bikejc.org/bike-bus/signup           200
# 28            https://new.bikejc.org/bike-bus/sign-up           200
# 29                     https://new.bikejc.org/sponsor           404
# 30         https://new.bikejc.org/about/board-members           200
# 31              https://new.bikejc.org/about/founding           200
# 32               https://new.bikejc.org/about/history           200
# 33  https://new.bikejc.org/about/non-profit-inform...           200
# 34          https://new.bikejc.org/bike-bus/aqua-line           200
# 35          https://new.bikejc.org/bike-bus/blue-line           200
# 36          https://new.bikejc.org/bike-bus/gold-line           200
# 37         https://new.bikejc.org/bike-bus/green-line           200
# 38                https://new.bikejc.org/bike-bus/map           200
# 39        https://new.bikejc.org/bike-bus/orange-line           200
# 40          https://new.bikejc.org/bike-bus/pink-line           200
# 41        https://new.bikejc.org/bike-bus/purple-line           200
# 42           https://new.bikejc.org/bike-bus/red-line           200
# 43        https://new.bikejc.org/bike-bus/silver-line           200
# 44          https://new.bikejc.org/bike-bus/teal-line           200
# 45        https://new.bikejc.org/bike-bus/yellow-line           200
# 46                  https://new.bikejc.org/contact-us           404
# 47  https://new.bikejc.org/events/bike-jcast/bike-...           200
# 48             https://new.bikejc.org/events/calendar           200
# 49  https://new.bikejc.org/news/articles/2016-ward...           404
# 50  https://new.bikejc.org/news/articles/bike-jc-a...           404
# 51  https://new.bikejc.org/news/articles/citi-bike...           404
# 52  https://new.bikejc.org/news/articles/design-bi...           404
# 53  https://new.bikejc.org/news/articles/footbridg...           404
# 54  https://new.bikejc.org/news/articles/grand-str...           404
# 55  https://new.bikejc.org/news/articles/installat...           404
# 56  https://new.bikejc.org/news/articles/jersey-ci...           404
# 57  https://new.bikejc.org/news/articles/job-posti...           404
# 58         https://new.bikejc.org/news/media-coverage           404
# 59         https://new.bikejc.org/projects/bike-lanes           404
# 60         https://new.bikejc.org/projects/bike-racks           404
# 61         https://new.bikejc.org/projects/bike-share           404
# 62                https://new.bikejc.org/projects/gsv           404
# 63                         https://new.bikejc.org/qrs           404
# 64  https://new.bikejc.org/resources/national-bike...           404
# 65        https://new.bikejc.org/resources/rules-road           404
# 66      https://new.bikejc.org/resources/useful-links           404
# 67  https://new.bikejc.org/support/cool-swag-cool-...           404
# 68              https://new.bikejc.org/support/donate           404
# 69            https://new.bikejc.org/support/sponsors           404
# 70           https://new.bikejc.org/support/volunteer           404
# 71                    https://new.bikejc.org/thankyou           404
# 72         https://new.bikejc.org/ward-tour/2022/faqs           200
# 73  https://new.bikejc.org/ward-tour/2022/finish-l...           200
# 74        https://new.bikejc.org/ward-tour/2022/route           200
# 75     https://new.bikejc.org/ward-tour/2022/sponsors           200
# 76    https://new.bikejc.org/ward-tour/2022/volunteer           200
# 77               https://new.bikejc.org/ward-tour/faq           200
#
#                                                   dst  \
# 0   mailto:bikebus@bikejc.org?subject=Sign%20up&bo...
# 1                                    /bike-bus/signup
# 2   https://actionnetwork.org/petitions/build-a-be...
# 3                                          /ward-tour
# 4                           /ward-tour/2022/volunteer
# 5                     /ward-tour/2022/ward-tour-route
# 6                /ward-tour/2022/finish-line-festival
# 7                  /ward-tour/2022/ward-tour-sponsors
# 8                                          /ward-tour
# 9                                      /ward-tour/faq
# 10  https://bikejc.regfox.com/ward-tour-2023?t=pal...
# 11  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 12  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 13                                     /ward-tour/faq
# 14                               /ward-tour/2022/faqs
# 15  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 16  https://bikejc.regfox.com/ward-tour-2023?t=ref...
# 17  https://docs.google.com/forms/d/e/1FAIpQLSeQQ4...
# 18                                          /bike-bus
# 19                                      /bike-bus/map
# 20                                   /bike-bus/signup
# 21                                          /bike-bus
# 22  https://na4.documents.adobe.com/public/esignWi...
# 23  https://na4.documents.adobe.com/public/esignWi...
# 24                                      /bike-bus/map
# 25  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 26  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 27  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 28  https://docs.google.com/forms/d/e/1FAIpQLSfyv5...
# 29                 /ward-tour-2023-sponsor-packet.pdf
# 30                              /about/board-members/
# 31                                   /about/founding/
# 32                                    /about/history/
# 33                     /about/non-profit-information/
# 34                               /bike-bus/aqua-line/
# 35                               /bike-bus/blue-line/
# 36                               /bike-bus/gold-line/
# 37                              /bike-bus/green-line/
# 38                                     /bike-bus/map/
# 39                             /bike-bus/orange-line/
# 40                               /bike-bus/pink-line/
# 41                             /bike-bus/purple-line/
# 42                                /bike-bus/red-line/
# 43                             /bike-bus/silver-line/
# 44                               /bike-bus/teal-line/
# 45                             /bike-bus/yellow-line/
# 46                                       /contact-us/
# 47                /events/bike-jcast/bike-jcast-2017/
# 48                                  /events/calendar/
# 49       /news/articles/2016-ward-tour-press-release/
# 50  /news/articles/bike-jc-awarded-jersey-city-gre...
# 51           /news/articles/citi-bike-jc-rebalancing/
# 52  /news/articles/design-bike-jcs-7th-annual-ward...
# 53  /news/articles/footbridge-liberty-state-park-a...
# 54  /news/articles/grand-street-vision-protected-b...
# 55  /news/articles/installation-jersey-citys-new-b...
# 56  /news/articles/jersey-citys-first-permanent-bi...
# 57  /news/articles/job-posting-contract-grant-writer/
# 58                              /news/media-coverage/
# 59                              /projects/bike-lanes/
# 60                              /projects/bike-racks/
# 61                              /projects/bike-share/
# 62                                     /projects/gsv/
# 63                                              /qrs/
# 64                 /resources/national-bike-registry/
# 65                             /resources/rules-road/
# 66                           /resources/useful-links/
# 67                    /support/cool-swag-cool-bikers/
# 68                                   /support/donate/
# 69                                 /support/sponsors/
# 70                                /support/volunteer/
# 71                                         /thankyou/
# 72                              /ward-tour/2022/faqs/
# 73              /ward-tour/2022/finish-line-festival/
# 74                             /ward-tour/2022/route/
# 75                          /ward-tour/2022/sponsors/
# 76                         /ward-tour/2022/volunteer/
# 77                                    /ward-tour/faq/
#
#                                           dst_new_url dst_new_code
# 0
# 1              https://new.bikejc.org/bike-bus/signup          200
# 2
# 3                    https://new.bikejc.org/ward-tour          200
# 4     https://new.bikejc.org/ward-tour/2022/volunteer          200
# 5   https://new.bikejc.org/ward-tour/2022/ward-tou...          200
# 6   https://new.bikejc.org/ward-tour/2022/finish-l...          200
# 7   https://new.bikejc.org/ward-tour/2022/ward-tou...          200
# 8                    https://new.bikejc.org/ward-tour          200
# 9                https://new.bikejc.org/ward-tour/faq          200
# 10
# 11
# 12
# 13               https://new.bikejc.org/ward-tour/faq          200
# 14         https://new.bikejc.org/ward-tour/2022/faqs          200
# 15
# 16
# 17
# 18                    https://new.bikejc.org/bike-bus          200
# 19                https://new.bikejc.org/bike-bus/map          200
# 20             https://new.bikejc.org/bike-bus/signup          200
# 21                    https://new.bikejc.org/bike-bus          200
# 22
# 23
# 24                https://new.bikejc.org/bike-bus/map          200
# 25
# 26
# 27
# 28
# 29  https://new.bikejc.org/ward-tour-2023-sponsor-...          404
# 30        https://new.bikejc.org/about/board-members/          200
# 31             https://new.bikejc.org/about/founding/          200
# 32              https://new.bikejc.org/about/history/          200
# 33  https://new.bikejc.org/about/non-profit-inform...          200
# 34         https://new.bikejc.org/bike-bus/aqua-line/          200
# 35         https://new.bikejc.org/bike-bus/blue-line/          200
# 36         https://new.bikejc.org/bike-bus/gold-line/          200
# 37        https://new.bikejc.org/bike-bus/green-line/          200
# 38               https://new.bikejc.org/bike-bus/map/          200
# 39       https://new.bikejc.org/bike-bus/orange-line/          200
# 40         https://new.bikejc.org/bike-bus/pink-line/          200
# 41       https://new.bikejc.org/bike-bus/purple-line/          200
# 42          https://new.bikejc.org/bike-bus/red-line/          200
# 43       https://new.bikejc.org/bike-bus/silver-line/          200
# 44         https://new.bikejc.org/bike-bus/teal-line/          200
# 45       https://new.bikejc.org/bike-bus/yellow-line/          200
# 46                 https://new.bikejc.org/contact-us/          404
# 47  https://new.bikejc.org/events/bike-jcast/bike-...          200
# 48            https://new.bikejc.org/events/calendar/          200
# 49  https://new.bikejc.org/news/articles/2016-ward...          404
# 50  https://new.bikejc.org/news/articles/bike-jc-a...          404
# 51  https://new.bikejc.org/news/articles/citi-bike...          404
# 52  https://new.bikejc.org/news/articles/design-bi...          404
# 53  https://new.bikejc.org/news/articles/footbridg...          404
# 54  https://new.bikejc.org/news/articles/grand-str...          404
# 55  https://new.bikejc.org/news/articles/installat...          404
# 56  https://new.bikejc.org/news/articles/jersey-ci...          404
# 57  https://new.bikejc.org/news/articles/job-posti...          404
# 58        https://new.bikejc.org/news/media-coverage/          404
# 59        https://new.bikejc.org/projects/bike-lanes/          404
# 60        https://new.bikejc.org/projects/bike-racks/          404
# 61        https://new.bikejc.org/projects/bike-share/          404
# 62               https://new.bikejc.org/projects/gsv/          404
# 63                        https://new.bikejc.org/qrs/          404
# 64  https://new.bikejc.org/resources/national-bike...          404
# 65       https://new.bikejc.org/resources/rules-road/          404
# 66     https://new.bikejc.org/resources/useful-links/          404
# 67  https://new.bikejc.org/support/cool-swag-cool-...          404
# 68             https://new.bikejc.org/support/donate/          404
# 69           https://new.bikejc.org/support/sponsors/          404
# 70          https://new.bikejc.org/support/volunteer/          404
# 71                   https://new.bikejc.org/thankyou/          404
# 72        https://new.bikejc.org/ward-tour/2022/faqs/          200
# 73  https://new.bikejc.org/ward-tour/2022/finish-l...          200
# 74       https://new.bikejc.org/ward-tour/2022/route/          200
# 75    https://new.bikejc.org/ward-tour/2022/sponsors/          200
# 76   https://new.bikejc.org/ward-tour/2022/volunteer/          200
# 77              https://new.bikejc.org/ward-tour/faq/          200

# %% [markdown]
# ### Write to "Redirects" sheet

# %%
spread.df_to_sheet(all_redirs, index=False, sheet='Redirects', replace=True)
